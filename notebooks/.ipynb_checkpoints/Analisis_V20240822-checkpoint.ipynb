# %% [markdown]
# # **0. Introduction**
# This notebook create different pipelines for machine learning models

# %%
# Import libraries

# Data Manipulation
import pandas as pd
import numpy as np

# Plots
import seaborn as sns
import matplotlib.pyplot as plt

# Data preprocessing
from sklearn.preprocessing import OneHotEncoder , OrdinalEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from scipy import stats
from sklearn.feature_extraction import FeatureHasher
from sklearn.compose import ColumnTransformer

# Data splitting
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import StratifiedKFold

# Feature Selection
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor

# Models
from xgboost import XGBRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import ExtraTreesRegressor , AdaBoostRegressor , BaggingRegressor
from sklearn.tree import DecisionTreeRegressor , ExtraTreeRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.neural_network import MLPRegressor

# Feature Selection
from xgboost import XGBClassifier
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.feature_selection import RFECV , RFE
from sklearn.svm import LinearSVC
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import mutual_info_regression

# Metrics
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import cross_val_score

# Hyperparameter optimization
from sklearn.model_selection import GridSearchCV

# Data imputation
from sklearn.impute import KNNImputer
from sklearn.impute import SimpleImputer

# Feature importance
import shap

# Genetic Algorithm
from deap import base, creator, tools, algorithms

# Utils
from itertools import product
import json
import time
import warnings
import pickle
from scipy.interpolate import make_interp_spline
from scipy.interpolate import interp1d
import pickle as pkl
from sklearn.pipeline import Pipeline , make_pipeline
import random
import joblib
warnings.filterwarnings("ignore")
# Set Numpy Seed
np.random.seed(0)
#plt.style.use('ggplot')
print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# # **1. Cargar información y preprocesamiento básico**

# %%
# Cargar información
ruta_archivo = r'..\data'
nombre_archivo = '\Resultados__nicos_Saber_Pro_20231019.csv'
tipo_de_dato = {'ESTU_CODDANE_COLE_TERMINO' : str}
data_1 = pd.read_csv(ruta_archivo + nombre_archivo).reset_index(drop = True)
# Dejar solo los resultados del programa de ingeniería industrial
filtro_academico = ['INGENIERIA INDUSTRIAL','INGENIERÍA INDUSTRIAL']
data_1 = data_1[data_1['ESTU_PRGM_ACADEMICO'].isin(filtro_academico)]
data_1
# Out:
#          PERIODO ESTU_CONSECUTIVO ESTU_TIPODOCUMENTO ESTU_PAIS_RESIDE  \
# 44         20183   EK201830190681                 CC         COLOMBIA
# 70         20183   EK201830032031                 CC         COLOMBIA
# 82         20183   EK201830091447                 CC         COLOMBIA
# 83         20183   EK201830118961                 CC         COLOMBIA
# 143        20183   EK201830002494                 CC         COLOMBIA
# ...          ...              ...                ...              ...
# 1217384    20222   EK202220137067                 CC         COLOMBIA
# 1217420    20222   EK202220199089                 CC         COLOMBIA
# 1217429    20222   EK202220124056                 CC         COLOMBIA
# 1217455    20222   EK202220205637                 CC         COLOMBIA
# 1217466    20222   EK202220210424                 CC         COLOMBIA
#
#          ESTU_COD_RESIDE_DEPTO ESTU_DEPTO_RESIDE  ESTU_COD_RESIDE_MCPIO  \
# 44                        76.0             VALLE                76001.0
# 70                        66.0         RISARALDA                66170.0
# 82                        11.0            BOGOTÁ                11001.0
# 83                         5.0         ANTIOQUIA                 5001.0
# 143                       11.0            BOGOTÁ                11001.0
# ...                        ...               ...                    ...
# 1217384                   11.0            BOGOTÁ                11001.0
# 1217420                   76.0             VALLE                76834.0
# 1217429                   41.0             HUILA                41306.0
# 1217455                   25.0      CUNDINAMARCA                25785.0
# 1217466                   11.0            BOGOTÁ                11001.0
#
#         ESTU_MCPIO_RESIDE  ESTU_CODDANE_COLE_TERMINO  \
# 44                   CALI                        NaN
# 70           DOSQUEBRADAS                        NaN
# 82            BOGOTÁ D.C.               1.251750e+11
# 83               MEDELLÍN               3.052660e+11
# 143           BOGOTÁ D.C.               3.080010e+11
# ...                   ...                        ...
# 1217384       BOGOTÁ D.C.               3.110010e+11
# 1217420             TULUÁ                        NaN
# 1217429           GIGANTE               2.413060e+11
# 1217455             TABIO                        NaN
# 1217466       BOGOTÁ D.C.               2.257970e+11
#
#          ESTU_COD_COLE_MCPIO_TERMINO  ...  FAMI_TIENEINTERNET  \
# 44                               NaN  ...                  Si
# 70                               NaN  ...                  Si
# 82                           25175.0  ...                  Si
# 83                            5266.0  ...                 NaN
# 143                           8001.0  ...                  Si
# ...                              ...  ...                 ...
# 1217384                      11001.0  ...                  Si
# 1217420                          NaN  ...                  Si
# 1217429                      41306.0  ...                  Si
# 1217455                          NaN  ...                  Si
# 1217466                      25797.0  ...                  Si
#
#                           FAMI_EDUCACIONMADRE               INST_ORIGEN  \
# 44       Secundaria (Bachillerato) incompleta  NO OFICIAL - CORPORACIÓN
# 70       Secundaria (Bachillerato) incompleta    NO OFICIAL - FUNDACIÓN
# 82       Secundaria (Bachillerato) incompleta  NO OFICIAL - CORPORACIÓN
# 83                                        NaN  NO OFICIAL - CORPORACIÓN
# 143            Educación profesional completa  NO OFICIAL - CORPORACIÓN
# ...                                       ...                       ...
# 1217384        Educación profesional completa    NO OFICIAL - FUNDACIÓN
# 1217420                               Ninguno    NO OFICIAL - FUNDACIÓN
# 1217429                             Postgrado  NO OFICIAL - CORPORACIÓN
# 1217455                   Primaria incompleta    NO OFICIAL - FUNDACIÓN
# 1217466        Técnica o tecnológica completa     OFICIAL DEPARTAMENTAL
#
#         MOD_RAZONA_CUANTITAT_PUNT MOD_COMUNI_ESCRITA_PUNT  \
# 44                            193                   153.0
# 70                            180                   146.0
# 82                            145                   140.0
# 83                            186                   148.0
# 143                           217                   199.0
# ...                           ...                     ...
# 1217384                       203                   128.0
# 1217420                       137                     0.0
# 1217429                       162                   133.0
# 1217455                       107                   107.0
# 1217466                       157                   133.0
#
#         MOD_COMUNI_ESCRITA_DESEM  MOD_INGLES_DESEM MOD_LECTURA_CRITICA_PUNT  \
# 44                           3.0                B1                      178
# 70                           2.0                A2                      158
# 82                           2.0                A1                      146
# 83                           2.0                B2                      190
# 143                          4.0                B2                      217
# ...                          ...               ...                      ...
# 1217384                      2.0                B1                      189
# 1217420                      NaN                A2                      145
# 1217429                      2.0                B1                      128
# 1217455                      1.0                A1                       77
# 1217466                      2.0                B1                      133
#
#         MOD_INGLES_PUNT MOD_COMPETEN_CIUDADA_PUNT
# 44                195.0                       182
# 70                170.0                       149
# 82                127.0                       178
# 83                214.0                       135
# 143               209.0                       217
# ...                 ...                       ...
# 1217384           186.0                       152
# 1217420           141.0                       163
# 1217429           168.0                       178
# 1217455           120.0                       127
# 1217466           169.0                       114
#
# [61353 rows x 57 columns]

# %%
# Definir las columnas de los puntajes
columnas_puntajes = ['MOD_RAZONA_CUANTITAT_PUNT',
                     'MOD_COMUNI_ESCRITA_PUNT',
                     'MOD_INGLES_PUNT',
                     'MOD_LECTURA_CRITICA_PUNT',
                     'MOD_COMPETEN_CIUDADA_PUNT']
# Quitar los valores nulos de las columnas de puntaje
data = data_1.copy()
for i in columnas_puntajes:
    data = data[data[i].isnull() == False]
data
# Out:
#          PERIODO ESTU_CONSECUTIVO ESTU_TIPODOCUMENTO ESTU_PAIS_RESIDE  \
# 44         20183   EK201830190681                 CC         COLOMBIA
# 70         20183   EK201830032031                 CC         COLOMBIA
# 82         20183   EK201830091447                 CC         COLOMBIA
# 83         20183   EK201830118961                 CC         COLOMBIA
# 143        20183   EK201830002494                 CC         COLOMBIA
# ...          ...              ...                ...              ...
# 1217384    20222   EK202220137067                 CC         COLOMBIA
# 1217420    20222   EK202220199089                 CC         COLOMBIA
# 1217429    20222   EK202220124056                 CC         COLOMBIA
# 1217455    20222   EK202220205637                 CC         COLOMBIA
# 1217466    20222   EK202220210424                 CC         COLOMBIA
#
#          ESTU_COD_RESIDE_DEPTO ESTU_DEPTO_RESIDE  ESTU_COD_RESIDE_MCPIO  \
# 44                        76.0             VALLE                76001.0
# 70                        66.0         RISARALDA                66170.0
# 82                        11.0            BOGOTÁ                11001.0
# 83                         5.0         ANTIOQUIA                 5001.0
# 143                       11.0            BOGOTÁ                11001.0
# ...                        ...               ...                    ...
# 1217384                   11.0            BOGOTÁ                11001.0
# 1217420                   76.0             VALLE                76834.0
# 1217429                   41.0             HUILA                41306.0
# 1217455                   25.0      CUNDINAMARCA                25785.0
# 1217466                   11.0            BOGOTÁ                11001.0
#
#         ESTU_MCPIO_RESIDE  ESTU_CODDANE_COLE_TERMINO  \
# 44                   CALI                        NaN
# 70           DOSQUEBRADAS                        NaN
# 82            BOGOTÁ D.C.               1.251750e+11
# 83               MEDELLÍN               3.052660e+11
# 143           BOGOTÁ D.C.               3.080010e+11
# ...                   ...                        ...
# 1217384       BOGOTÁ D.C.               3.110010e+11
# 1217420             TULUÁ                        NaN
# 1217429           GIGANTE               2.413060e+11
# 1217455             TABIO                        NaN
# 1217466       BOGOTÁ D.C.               2.257970e+11
#
#          ESTU_COD_COLE_MCPIO_TERMINO  ...  FAMI_TIENEINTERNET  \
# 44                               NaN  ...                  Si
# 70                               NaN  ...                  Si
# 82                           25175.0  ...                  Si
# 83                            5266.0  ...                 NaN
# 143                           8001.0  ...                  Si
# ...                              ...  ...                 ...
# 1217384                      11001.0  ...                  Si
# 1217420                          NaN  ...                  Si
# 1217429                      41306.0  ...                  Si
# 1217455                          NaN  ...                  Si
# 1217466                      25797.0  ...                  Si
#
#                           FAMI_EDUCACIONMADRE               INST_ORIGEN  \
# 44       Secundaria (Bachillerato) incompleta  NO OFICIAL - CORPORACIÓN
# 70       Secundaria (Bachillerato) incompleta    NO OFICIAL - FUNDACIÓN
# 82       Secundaria (Bachillerato) incompleta  NO OFICIAL - CORPORACIÓN
# 83                                        NaN  NO OFICIAL - CORPORACIÓN
# 143            Educación profesional completa  NO OFICIAL - CORPORACIÓN
# ...                                       ...                       ...
# 1217384        Educación profesional completa    NO OFICIAL - FUNDACIÓN
# 1217420                               Ninguno    NO OFICIAL - FUNDACIÓN
# 1217429                             Postgrado  NO OFICIAL - CORPORACIÓN
# 1217455                   Primaria incompleta    NO OFICIAL - FUNDACIÓN
# 1217466        Técnica o tecnológica completa     OFICIAL DEPARTAMENTAL
#
#         MOD_RAZONA_CUANTITAT_PUNT MOD_COMUNI_ESCRITA_PUNT  \
# 44                            193                   153.0
# 70                            180                   146.0
# 82                            145                   140.0
# 83                            186                   148.0
# 143                           217                   199.0
# ...                           ...                     ...
# 1217384                       203                   128.0
# 1217420                       137                     0.0
# 1217429                       162                   133.0
# 1217455                       107                   107.0
# 1217466                       157                   133.0
#
#         MOD_COMUNI_ESCRITA_DESEM  MOD_INGLES_DESEM MOD_LECTURA_CRITICA_PUNT  \
# 44                           3.0                B1                      178
# 70                           2.0                A2                      158
# 82                           2.0                A1                      146
# 83                           2.0                B2                      190
# 143                          4.0                B2                      217
# ...                          ...               ...                      ...
# 1217384                      2.0                B1                      189
# 1217420                      NaN                A2                      145
# 1217429                      2.0                B1                      128
# 1217455                      1.0                A1                       77
# 1217466                      2.0                B1                      133
#
#         MOD_INGLES_PUNT MOD_COMPETEN_CIUDADA_PUNT
# 44                195.0                       182
# 70                170.0                       149
# 82                127.0                       178
# 83                214.0                       135
# 143               209.0                       217
# ...                 ...                       ...
# 1217384           186.0                       152
# 1217420           141.0                       163
# 1217429           168.0                       178
# 1217455           120.0                       127
# 1217466           169.0                       114
#
# [61021 rows x 57 columns]

# %%
# Crear la columna de target como el promedio de todos los puntajes
data['PUNTAJE_GLOBAL'] = data[columnas_puntajes].mean(axis = 1)
data
# Out:
#          PERIODO ESTU_CONSECUTIVO ESTU_TIPODOCUMENTO ESTU_PAIS_RESIDE  \
# 44         20183   EK201830190681                 CC         COLOMBIA
# 70         20183   EK201830032031                 CC         COLOMBIA
# 82         20183   EK201830091447                 CC         COLOMBIA
# 83         20183   EK201830118961                 CC         COLOMBIA
# 143        20183   EK201830002494                 CC         COLOMBIA
# ...          ...              ...                ...              ...
# 1217384    20222   EK202220137067                 CC         COLOMBIA
# 1217420    20222   EK202220199089                 CC         COLOMBIA
# 1217429    20222   EK202220124056                 CC         COLOMBIA
# 1217455    20222   EK202220205637                 CC         COLOMBIA
# 1217466    20222   EK202220210424                 CC         COLOMBIA
#
#          ESTU_COD_RESIDE_DEPTO ESTU_DEPTO_RESIDE  ESTU_COD_RESIDE_MCPIO  \
# 44                        76.0             VALLE                76001.0
# 70                        66.0         RISARALDA                66170.0
# 82                        11.0            BOGOTÁ                11001.0
# 83                         5.0         ANTIOQUIA                 5001.0
# 143                       11.0            BOGOTÁ                11001.0
# ...                        ...               ...                    ...
# 1217384                   11.0            BOGOTÁ                11001.0
# 1217420                   76.0             VALLE                76834.0
# 1217429                   41.0             HUILA                41306.0
# 1217455                   25.0      CUNDINAMARCA                25785.0
# 1217466                   11.0            BOGOTÁ                11001.0
#
#         ESTU_MCPIO_RESIDE  ESTU_CODDANE_COLE_TERMINO  \
# 44                   CALI                        NaN
# 70           DOSQUEBRADAS                        NaN
# 82            BOGOTÁ D.C.               1.251750e+11
# 83               MEDELLÍN               3.052660e+11
# 143           BOGOTÁ D.C.               3.080010e+11
# ...                   ...                        ...
# 1217384       BOGOTÁ D.C.               3.110010e+11
# 1217420             TULUÁ                        NaN
# 1217429           GIGANTE               2.413060e+11
# 1217455             TABIO                        NaN
# 1217466       BOGOTÁ D.C.               2.257970e+11
#
#          ESTU_COD_COLE_MCPIO_TERMINO  ...  \
# 44                               NaN  ...
# 70                               NaN  ...
# 82                           25175.0  ...
# 83                            5266.0  ...
# 143                           8001.0  ...
# ...                              ...  ...
# 1217384                      11001.0  ...
# 1217420                          NaN  ...
# 1217429                      41306.0  ...
# 1217455                          NaN  ...
# 1217466                      25797.0  ...
#
#                           FAMI_EDUCACIONMADRE               INST_ORIGEN  \
# 44       Secundaria (Bachillerato) incompleta  NO OFICIAL - CORPORACIÓN
# 70       Secundaria (Bachillerato) incompleta    NO OFICIAL - FUNDACIÓN
# 82       Secundaria (Bachillerato) incompleta  NO OFICIAL - CORPORACIÓN
# 83                                        NaN  NO OFICIAL - CORPORACIÓN
# 143            Educación profesional completa  NO OFICIAL - CORPORACIÓN
# ...                                       ...                       ...
# 1217384        Educación profesional completa    NO OFICIAL - FUNDACIÓN
# 1217420                               Ninguno    NO OFICIAL - FUNDACIÓN
# 1217429                             Postgrado  NO OFICIAL - CORPORACIÓN
# 1217455                   Primaria incompleta    NO OFICIAL - FUNDACIÓN
# 1217466        Técnica o tecnológica completa     OFICIAL DEPARTAMENTAL
#
#         MOD_RAZONA_CUANTITAT_PUNT MOD_COMUNI_ESCRITA_PUNT  \
# 44                            193                   153.0
# 70                            180                   146.0
# 82                            145                   140.0
# 83                            186                   148.0
# 143                           217                   199.0
# ...                           ...                     ...
# 1217384                       203                   128.0
# 1217420                       137                     0.0
# 1217429                       162                   133.0
# 1217455                       107                   107.0
# 1217466                       157                   133.0
#
#         MOD_COMUNI_ESCRITA_DESEM MOD_INGLES_DESEM  MOD_LECTURA_CRITICA_PUNT  \
# 44                           3.0               B1                       178
# 70                           2.0               A2                       158
# 82                           2.0               A1                       146
# 83                           2.0               B2                       190
# 143                          4.0               B2                       217
# ...                          ...              ...                       ...
# 1217384                      2.0               B1                       189
# 1217420                      NaN               A2                       145
# 1217429                      2.0               B1                       128
# 1217455                      1.0               A1                        77
# 1217466                      2.0               B1                       133
#
#         MOD_INGLES_PUNT MOD_COMPETEN_CIUDADA_PUNT PUNTAJE_GLOBAL
# 44                195.0                       182          180.2
# 70                170.0                       149          160.6
# 82                127.0                       178          147.2
# 83                214.0                       135          174.6
# 143               209.0                       217          211.8
# ...                 ...                       ...            ...
# 1217384           186.0                       152          171.6
# 1217420           141.0                       163          117.2
# 1217429           168.0                       178          153.8
# 1217455           120.0                       127          107.6
# 1217466           169.0                       114          141.2
#
# [61021 rows x 58 columns]

# %%
# Mostrar columnas
data.columns.tolist()
# Out:
# ['PERIODO',
#  'ESTU_CONSECUTIVO',
#  'ESTU_TIPODOCUMENTO',
#  'ESTU_PAIS_RESIDE',
#  'ESTU_COD_RESIDE_DEPTO',
#  'ESTU_DEPTO_RESIDE',
#  'ESTU_COD_RESIDE_MCPIO',
#  'ESTU_MCPIO_RESIDE',
#  'ESTU_CODDANE_COLE_TERMINO',
#  'ESTU_COD_COLE_MCPIO_TERMINO',
#  'ESTU_COD_DEPTO_PRESENTACION',
#  'INST_COD_INSTITUCION',
#  'INST_NOMBRE_INSTITUCION',
#  'INST_CARACTER_ACADEMICO',
#  'ESTU_NUCLEO_PREGRADO',
#  'ESTU_INST_DEPARTAMENTO',
#  'ESTU_INST_CODMUNICIPIO',
#  'ESTU_INST_MUNICIPIO',
#  'ESTU_PRGM_ACADEMICO',
#  'ESTU_PRGM_DEPARTAMENTO',
#  'ESTU_PRGM_CODMUNICIPIO',
#  'ESTU_PRGM_MUNICIPIO',
#  'ESTU_NIVEL_PRGM_ACADEMICO',
#  'ESTU_METODO_PRGM',
#  'ESTU_VALORMATRICULAUNIVERSIDAD',
#  'ESTU_DEPTO_PRESENTACION',
#  'ESTU_COD_MCPIO_PRESENTACION',
#  'ESTU_MCPIO_PRESENTACION',
#  'ESTU_PAGOMATRICULABECA',
#  'ESTU_PAGOMATRICULACREDITO',
#  'ESTU_HORASSEMANATRABAJA',
#  'ESTU_SNIES_PRGMACADEMICO',
#  'ESTU_PRIVADO_LIBERTAD',
#  'ESTU_NACIONALIDAD',
#  'ESTU_ESTUDIANTE',
#  'ESTU_GENERO',
#  'ESTU_COLE_TERMINO',
#  'ESTU_PAGOMATRICULAPADRES',
#  'ESTU_ESTADOINVESTIGACION',
#  'ESTU_FECHANACIMIENTO',
#  'ESTU_PAGOMATRICULAPROPIO',
#  'ESTU_TIPODOCUMENTOSB11',
#  'FAMI_EDUCACIONPADRE',
#  'FAMI_TIENEAUTOMOVIL',
#  'FAMI_TIENELAVADORA',
#  'FAMI_ESTRATOVIVIENDA',
#  'FAMI_TIENECOMPUTADOR',
#  'FAMI_TIENEINTERNET',
#  'FAMI_EDUCACIONMADRE',
#  'INST_ORIGEN',
#  'MOD_RAZONA_CUANTITAT_PUNT',
#  'MOD_COMUNI_ESCRITA_PUNT',
#  'MOD_COMUNI_ESCRITA_DESEM',
#  'MOD_INGLES_DESEM',
#  'MOD_LECTURA_CRITICA_PUNT',
#  'MOD_INGLES_PUNT',
#  'MOD_COMPETEN_CIUDADA_PUNT',
#  'PUNTAJE_GLOBAL']

# %%
# Mostrar el número de instituciones por año, evaluadas.
aux_periodos = pd.DataFrame()
for i in data['PERIODO'].unique().tolist():
    aux = pd.DataFrame({'Periodo' : [str(i)[:4]  + str(i)[-1:].zfill(2)],
                        'Total Instituciones' :len(data[data['PERIODO'] == i]['INST_NOMBRE_INSTITUCION'].unique().tolist())})
    aux_periodos = pd.concat([aux_periodos,
                              aux] , axis = 0)
aux_periodos.sort_values(by = 'Periodo')
# Out:
#   Periodo  Total Instituciones
# 0  201803                  101
# 0  201804                    6
# 0  201904                   29
# 0  201905                  105
# 0  201906                    8
# 0  202002                   10
# 0  202003                  107
# 0  202102                  111
# 0  202103                   30
# 0  202202                   98
# 0  202203                   13
# 0  202205                  116
# 0  202206                   12

# %%
# Definir Target y tipos de datos
target = ['PUNTAJE_GLOBAL'] +  ['MOD_RAZONA_CUANTITAT_PUNT',
                                 'MOD_COMUNI_ESCRITA_PUNT',
                                 'MOD_INGLES_PUNT',
                                 'MOD_LECTURA_CRITICA_PUNT',
                                 'MOD_COMPETEN_CIUDADA_PUNT']
ignore_columns = [ 'PERIODO', 'ESTU_CONSECUTIVO', 'ESTU_TIPODOCUMENTO' ,'ESTU_PAIS_RESIDE', 'ESTU_DEPTO_RESIDE', 'ESTU_MCPIO_RESIDE',
                  'ESTU_COD_COLE_MCPIO_TERMINO', 'INST_NOMBRE_INSTITUCION' ,'ESTU_NUCLEO_PREGRADO' , 'ESTU_INST_DEPARTAMENTO' , 'ESTU_INST_CODMUNICIPIO',
                  'ESTU_INST_MUNICIPIO' , 'ESTU_PRGM_DEPARTAMENTO' , 'ESTU_PRGM_CODMUNICIPIO' , 'ESTU_PRGM_MUNICIPIO' , 'ESTU_DEPTO_PRESENTACION' , 'ESTU_COD_MCPIO_PRESENTACION',
                  'ESTU_MCPIO_PRESENTACION' , 'ESTU_NACIONALIDAD' , 'ESTU_ESTUDIANTE' , 'ESTU_COLE_TERMINO' , 'ESTU_TIPODOCUMENTOSB11' , 'ESTU_FECHANACIMIENTO',
                  'ESTU_CODDANE_COLE_TERMINO' , 'MOD_INGLES_DESEM' , 'ESTU_NIVEL_PRGM_ACADEMICO' , 'ESTU_PRIVADO_LIBERTAD' , 'MOD_COMUNI_ESCRITA_DESEM',
                 'ESTU_COD_RESIDE_MCPIO' , 'ESTU_PRGM_ACADEMICO', 'ESTU_SNIES_PRGMACADEMICO']
ordinal_features = ['ESTU_VALORMATRICULAUNIVERSIDAD' , 'ESTU_HORASSEMANATRABAJA' , 'FAMI_ESTRATOVIVIENDA',
                   'FAMI_EDUCACIONPADRE' , 'FAMI_EDUCACIONMADRE']
numeric_features = []
categorical_features = [i for i in data.columns.tolist() if i not in target and i not in numeric_features and i not in ignore_columns and i not in ordinal_features]
categorical_features
# Out:
# ['ESTU_COD_RESIDE_DEPTO',
#  'ESTU_COD_DEPTO_PRESENTACION',
#  'INST_COD_INSTITUCION',
#  'INST_CARACTER_ACADEMICO',
#  'ESTU_METODO_PRGM',
#  'ESTU_PAGOMATRICULABECA',
#  'ESTU_PAGOMATRICULACREDITO',
#  'ESTU_GENERO',
#  'ESTU_PAGOMATRICULAPADRES',
#  'ESTU_ESTADOINVESTIGACION',
#  'ESTU_PAGOMATRICULAPROPIO',
#  'FAMI_TIENEAUTOMOVIL',
#  'FAMI_TIENELAVADORA',
#  'FAMI_TIENECOMPUTADOR',
#  'FAMI_TIENEINTERNET',
#  'INST_ORIGEN']

# %% [markdown]
# # **2. Exploración de datos**

# %%
# Quitar las columnas que se ignoran
data = data.drop(columns = ignore_columns)

# %%
# Describe data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61021 entries, 44 to 1217466
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ESTU_COD_RESIDE_DEPTO           60882 non-null  float64
#  1   ESTU_COD_DEPTO_PRESENTACION     61020 non-null  float64
#  2   INST_COD_INSTITUCION            61021 non-null  int64
#  3   INST_CARACTER_ACADEMICO         61021 non-null  object
#  4   ESTU_METODO_PRGM                61021 non-null  object
#  5   ESTU_VALORMATRICULAUNIVERSIDAD  60403 non-null  object
#  6   ESTU_PAGOMATRICULABECA          60388 non-null  object
#  7   ESTU_PAGOMATRICULACREDITO       60390 non-null  object
#  8   ESTU_HORASSEMANATRABAJA         58602 non-null  object
#  9   ESTU_GENERO                     61016 non-null  object
#  10  ESTU_PAGOMATRICULAPADRES        60387 non-null  object
#  11  ESTU_ESTADOINVESTIGACION        61021 non-null  object
#  12  ESTU_PAGOMATRICULAPROPIO        60394 non-null  object
#  13  FAMI_EDUCACIONPADRE             59289 non-null  object
#  14  FAMI_TIENEAUTOMOVIL             57577 non-null  object
#  15  FAMI_TIENELAVADORA              57970 non-null  object
#  16  FAMI_ESTRATOVIVIENDA            58689 non-null  object
#  17  FAMI_TIENECOMPUTADOR            58130 non-null  object
#  18  FAMI_TIENEINTERNET              58974 non-null  object
#  19  FAMI_EDUCACIONMADRE             59241 non-null  object
#  20  INST_ORIGEN                     61021 non-null  object
#  21  MOD_RAZONA_CUANTITAT_PUNT       61021 non-null  int64
#  22  MOD_COMUNI_ESCRITA_PUNT         61021 non-null  float64
#  23  MOD_LECTURA_CRITICA_PUNT        61021 non-null  int64
#  24  MOD_INGLES_PUNT                 61021 non-null  float64
#  25  MOD_COMPETEN_CIUDADA_PUNT       61021 non-null  int64
#  26  PUNTAJE_GLOBAL                  61021 non-null  float64
# dtypes: float64(5), int64(4), object(18)
# memory usage: 13.0+ MB

# %%
data.describe()
# Out:
#        ESTU_COD_RESIDE_DEPTO  ESTU_COD_DEPTO_PRESENTACION  \
# count           60882.000000                 61020.000000
# mean               92.319651                    20.284677
# std              2496.917863                    20.395082
# min                 0.000000                     0.000000
# 25%                11.000000                    11.000000
# 50%                13.000000                    11.000000
# 75%                54.000000                    13.000000
# max             99999.000000                    99.000000
#
#        INST_COD_INSTITUCION  MOD_RAZONA_CUANTITAT_PUNT  \
# count          61021.000000               61021.000000
# mean            2499.233198                 160.030039
# std             1436.310905                  32.217025
# min             1101.000000                   0.000000
# 25%             1713.000000                 139.000000
# 50%             2102.000000                 161.000000
# 75%             2823.000000                 183.000000
# max             9914.000000                 300.000000
#
#        MOD_COMUNI_ESCRITA_PUNT  MOD_LECTURA_CRITICA_PUNT  MOD_INGLES_PUNT  \
# count             61021.000000              61021.000000     61021.000000
# mean                138.621589                149.314007       157.023861
# std                  40.796138                 30.539235        31.405383
# min                   0.000000                  0.000000         0.000000
# 25%                 124.000000                127.000000       136.000000
# 50%                 140.000000                150.000000       155.000000
# 75%                 164.000000                171.000000       177.000000
# max                 300.000000                300.000000       300.000000
#
#        MOD_COMPETEN_CIUDADA_PUNT  PUNTAJE_GLOBAL
# count               61021.000000    61021.000000
# mean                  145.068911      150.011681
# std                    33.302400       25.024995
# min                     0.000000        0.000000
# 25%                   122.000000      133.400000
# 50%                   147.000000      149.400000
# 75%                   169.000000      167.000000
# max                   300.000000      264.800000

# %%
# Mostrar valores nulos
null_values_count = pd.DataFrame(data.isnull().sum() / data.shape[0]).sort_values(by = 0 , ascending = False).T
null_values_count = null_values_count.T.reset_index()
null_values_count.columns = ['Variable' , '% de nulos']
null_values_count.index = null_values_count['Variable']
null_values_count = null_values_count.drop(columns = ['Variable'])
null_values_count['% de nulos'] = round(null_values_count['% de nulos'] * 100 , 2)
null_values_count
# Out:
#                                 % de nulos
# Variable
# FAMI_TIENEAUTOMOVIL                   5.64
# FAMI_TIENELAVADORA                    5.00
# FAMI_TIENECOMPUTADOR                  4.74
# ESTU_HORASSEMANATRABAJA               3.96
# FAMI_ESTRATOVIVIENDA                  3.82
# FAMI_TIENEINTERNET                    3.35
# FAMI_EDUCACIONMADRE                   2.92
# FAMI_EDUCACIONPADRE                   2.84
# ESTU_PAGOMATRICULAPADRES              1.04
# ESTU_PAGOMATRICULABECA                1.04
# ESTU_PAGOMATRICULACREDITO             1.03
# ESTU_PAGOMATRICULAPROPIO              1.03
# ESTU_VALORMATRICULAUNIVERSIDAD        1.01
# ESTU_COD_RESIDE_DEPTO                 0.23
# ESTU_GENERO                           0.01
# ESTU_COD_DEPTO_PRESENTACION           0.00
# ESTU_ESTADOINVESTIGACION              0.00
# ESTU_METODO_PRGM                      0.00
# INST_CARACTER_ACADEMICO               0.00
# INST_COD_INSTITUCION                  0.00
# INST_ORIGEN                           0.00
# MOD_RAZONA_CUANTITAT_PUNT             0.00
# MOD_COMUNI_ESCRITA_PUNT               0.00
# MOD_LECTURA_CRITICA_PUNT              0.00
# MOD_INGLES_PUNT                       0.00
# MOD_COMPETEN_CIUDADA_PUNT             0.00
# PUNTAJE_GLOBAL                        0.00

# %%
# Quitar categorias con más del 10% de nans
to_drop_features = [i for i in null_values_count.T.columns.tolist() if null_values_count.T[i].values[0] > 10]
data = data.drop(columns = to_drop_features)
# Re definir variables
categorical_features = [i for i in categorical_features if i in data.columns.tolist()]
numeric_features = [i for i in numeric_features if i in data.columns.tolist()]
print('Variables Eliminadas:')
to_drop_features
# Out:
# Variables Eliminadas:
# []

# %%
# Mostrar distribución del target
for i in target:
    plt.figure()
    sns.distplot(data[i])
    plt.title('Distribución del target ' + str(i))
    plt.legend([f'Media: {round(data[i].values.mean())}\nDesviación Estandar: {round(data[i].values.std())}\nMáximo: {round(data[i].values.max())}'], loc='upper left')
    plt.ylabel('Frecuencia')
    plt.show()

# %%
# Realizar gráfico de distribución del target por cada una de las variables categóricas y ordinales
excluir_grafico = ['ESTU_COD_RESIDE_DEPTO' , 'ESTU_COD_RESIDE_MCPIO' , 'ESTU_COD_DEPTO_PRESENTACION' , 'INST_COD_INSTITUCION' , 'ESTU_SNIES_PRGMACADEMICO',
                  'ESTU_PRGM_ACADEMICO']
for i in ['PUNTAJE_GLOBAL']:
    for j in data.columns.tolist():
        if j not in numeric_features and j not in target and j not in excluir_grafico:
            # Realizar la prueba de chi-cuadrado
            contingency_table = pd.crosstab(data[i], data[j])
            chi2, p, dof, ex = stats.chi2_contingency(contingency_table)
            sns.displot(data, x = i, hue = j)
            plt.title(f'Distribución de {i} con respecto a la variable {j}\nChi2 p-valor: {p:.4f}')
            plt.ylabel('Número Observaciones')
            plt.show()

# %%
# Codificar las variables oridnales
codificador_ordinales = pd.read_excel('..\data\Parametros.xlsx' ,
                                      sheet_name = 'Codificacion_Ordinales',
                                      dtype = {'COLUMNA' : str , 
                                                'VALOR_ACTUAL' : str})
for i in ordinal_features:
    print('Categorizando variable -->' , i)
    aux = codificador_ordinales[codificador_ordinales['COLUMNA'] == i]
    data[i + '_ENCODED'] = data[i].map(dict(aux[['VALOR_ACTUAL' , 'VALOR_CODIFICADO']].values))
# Actualizar las variables ordinales
ordinal_features = [i for i in data.columns.tolist() if '_ENCODED' in i]
print('Nuevas variables oridnales:' , ordinal_features)
data
# Out:
# Categorizando variable --> ESTU_VALORMATRICULAUNIVERSIDAD
# Categorizando variable --> ESTU_HORASSEMANATRABAJA
# Categorizando variable --> FAMI_ESTRATOVIVIENDA
# Categorizando variable --> FAMI_EDUCACIONPADRE
# Categorizando variable --> FAMI_EDUCACIONMADRE
# Nuevas variables oridnales: ['ESTU_VALORMATRICULAUNIVERSIDAD_ENCODED', 'ESTU_HORASSEMANATRABAJA_ENCODED', 'FAMI_ESTRATOVIVIENDA_ENCODED', 'FAMI_EDUCACIONPADRE_ENCODED', 'FAMI_EDUCACIONMADRE_ENCODED']
#          ESTU_COD_RESIDE_DEPTO  ESTU_COD_DEPTO_PRESENTACION  \
# 44                        76.0                         76.0
# 70                        66.0                         66.0
# 82                        11.0                         11.0
# 83                         5.0                          5.0
# 143                       11.0                         11.0
# ...                        ...                          ...
# 1217384                   11.0                         11.0
# 1217420                   76.0                         76.0
# 1217429                   41.0                         11.0
# 1217455                   25.0                         25.0
# 1217466                   11.0                         11.0
#
#          INST_COD_INSTITUCION    INST_CARACTER_ACADEMICO  ESTU_METODO_PRGM  \
# 44                       1805                UNIVERSIDAD        PRESENCIAL
# 70                       2711                UNIVERSIDAD        PRESENCIAL
# 82                       5802                UNIVERSIDAD        PRESENCIAL
# 83                       2813                UNIVERSIDAD        PRESENCIAL
# 143                      1813                UNIVERSIDAD        PRESENCIAL
# ...                       ...                        ...               ...
# 1217384                  1709                UNIVERSIDAD        PRESENCIAL
# 1217420                  2725  INSTITUCIÓN UNIVERSITARIA  DISTANCIA VITUAL
# 1217429                  2828  INSTITUCIÓN UNIVERSITARIA        PRESENCIAL
# 1217455                  2725  INSTITUCIÓN UNIVERSITARIA  DISTANCIA VITUAL
# 1217466                  9899  INSTITUCIÓN UNIVERSITARIA        PRESENCIAL
#
#                    ESTU_VALORMATRICULAUNIVERSIDAD ESTU_PAGOMATRICULABECA  \
# 44       Entre 4 millones y menos de 5.5 millones                     No
# 70       Entre 4 millones y menos de 5.5 millones                     Si
# 82       Entre 2.5 millones y menos de 4 millones                     No
# 83                              Más de 7 millones                     No
# 143                             Más de 7 millones                     Si
# ...                                           ...                    ...
# 1217384  Entre 4 millones y menos de 5.5 millones                     No
# 1217420  Entre 2.5 millones y menos de 4 millones                     Si
# 1217429  Entre 2.5 millones y menos de 4 millones                     No
# 1217455    Entre 1 millón y menos de 2.5 millones                     No
# 1217466    Entre 1 millón y menos de 2.5 millones                     No
#
#         ESTU_PAGOMATRICULACREDITO ESTU_HORASSEMANATRABAJA ESTU_GENERO  ...  \
# 44                             No         Más de 30 horas           M  ...
# 70                             Si     Entre 11 y 20 horas           M  ...
# 82                             No     Entre 21 y 30 horas           F  ...
# 83                             No                     NaN           F  ...
# 143                            No                       0           F  ...
# ...                           ...                     ...         ...  ...
# 1217384                        Si                       0           M  ...
# 1217420                        Si     Entre 11 y 20 horas           F  ...
# 1217429                        No     Entre 11 y 20 horas           M  ...
# 1217455                        No         Más de 30 horas           F  ...
# 1217466                        No         Más de 30 horas           M  ...
#
#         MOD_COMUNI_ESCRITA_PUNT MOD_LECTURA_CRITICA_PUNT MOD_INGLES_PUNT  \
# 44                        153.0                      178           195.0
# 70                        146.0                      158           170.0
# 82                        140.0                      146           127.0
# 83                        148.0                      190           214.0
# 143                       199.0                      217           209.0
# ...                         ...                      ...             ...
# 1217384                   128.0                      189           186.0
# 1217420                     0.0                      145           141.0
# 1217429                   133.0                      128           168.0
# 1217455                   107.0                       77           120.0
# 1217466                   133.0                      133           169.0
#
#         MOD_COMPETEN_CIUDADA_PUNT PUNTAJE_GLOBAL  \
# 44                            182          180.2
# 70                            149          160.6
# 82                            178          147.2
# 83                            135          174.6
# 143                           217          211.8
# ...                           ...            ...
# 1217384                       152          171.6
# 1217420                       163          117.2
# 1217429                       178          153.8
# 1217455                       127          107.6
# 1217466                       114          141.2
#
#         ESTU_VALORMATRICULAUNIVERSIDAD_ENCODED  \
# 44                                           5
# 70                                           5
# 82                                           4
# 83                                           7
# 143                                          7
# ...                                        ...
# 1217384                                      5
# 1217420                                      4
# 1217429                                      4
# 1217455                                      3
# 1217466                                      3
#
#         ESTU_HORASSEMANATRABAJA_ENCODED FAMI_ESTRATOVIVIENDA_ENCODED  \
# 44                                    4                            3
# 70                                    2                            3
# 82                                    3                            3
# 83                                   -1                           -1
# 143                                   0                            3
# ...                                 ...                          ...
# 1217384                               0                            3
# 1217420                               2                            2
# 1217429                               2                            2
# 1217455                               4                            2
# 1217466                               4                            2
#
#         FAMI_EDUCACIONPADRE_ENCODED FAMI_EDUCACIONMADRE_ENCODED
# 44                                3                           3
# 70                                6                           3
# 82                                6                           3
# 83                               -1                          -1
# 143                               8                           8
# ...                             ...                         ...
# 1217384                           8                           8
# 1217420                           0                           0
# 1217429                           6                           9
# 1217455                           1                           1
# 1217466                           2                           6
#
# [61021 rows x 32 columns]

# %%
# Mostrar valores variables categoricas
for i in list(data.columns):
    if i not in numeric_features and i not in target:
        print('-' * 50)
        print(f'{i :-<20} : {data[i].unique()} : Total valores unicos : {len(data[i].unique().tolist())}')
# Out:
# --------------------------------------------------
# ESTU_COD_RESIDE_DEPTO : [7.6000e+01 6.6000e+01 1.1000e+01 5.0000e+00 6.8000e+01 2.5000e+01
#  8.0000e+00 1.3000e+01 4.1000e+01 7.0000e+01 1.9000e+01 1.5000e+01
#  5.0000e+01 7.3000e+01 4.7000e+01 5.2000e+01 8.1000e+01 8.6000e+01
#  2.3000e+01 1.7000e+01 4.4000e+01 6.3000e+01 5.4000e+01 2.0000e+01
#  9.5000e+01        nan 2.7000e+01 8.5000e+01 1.8000e+01 9.4000e+01
#  8.8000e+01 9.9000e+01 9.9999e+04 9.7000e+01 9.1000e+01 0.0000e+00] : Total valores unicos : 36
# --------------------------------------------------
# ESTU_COD_DEPTO_PRESENTACION : [76. 66. 11.  5. 68. 25.  8. 13. 41. 70. 19. 15. 50. 73. 47.  0. 54. 86.
#  23. 17. 44. 81. 95. 63. 52. 20. 85. 88. 18. 27. 99. 94. nan 91.] : Total valores unicos : 34
# --------------------------------------------------
# INST_COD_INSTITUCION : [1805 2711 5802 2813 1813 2847 2102 1202 1204 1709 2725 4702 3705 1710
#  1719 1705 2828 2823 1301 1214 1828 2715 1111 2738 1826 1807 1818 1803
#  1701 9119 2301 1203 1716 2810 1831 1713 2820 1213 1723 1804 2713 1725
#  1212 2837 1113 1201 1825 2834 2811 4726 2829 1830 1218 3821 1702 4709
#  1101 1117 3831 1703 1707 2832 1729 1209 1812 3803 1726 1103 2749 1717
#  2848 1711 1814 2840 1832 1727 1715 1806 2805 2731 1102 1834 1732 1728
#  9899 3301 1823 2827 1808 2723 1734 1810 3107 2833 1704 3117 2712 1735
#  9129 9907 9122 2830 1833 1108 9121 9914 2812 9116 1819 2842 2719 2728
#  2737 4813 2841 2831 2302] : Total valores unicos : 117
# --------------------------------------------------
# INST_CARACTER_ACADEMICO : ['UNIVERSIDAD' 'INSTITUCIÓN UNIVERSITARIA' 'INSTITUCIÓN TECNOLÓGICA'
#  'TÉCNICA PROFESIONAL'] : Total valores unicos : 4
# --------------------------------------------------
# ESTU_METODO_PRGM---- : ['PRESENCIAL' 'DISTANCIA' 'DISTANCIA VITUAL'] : Total valores unicos : 3
# --------------------------------------------------
# ESTU_VALORMATRICULAUNIVERSIDAD : ['Entre 4 millones y menos de 5.5 millones'
#  'Entre 2.5 millones y menos de 4 millones' 'Más de 7 millones'
#  'Entre 1 millón y menos de 2.5 millones' 'Menos de 500 mil'
#  'Entre 500 mil y menos de 1 millón'
#  'Entre 5.5 millones y menos de 7 millones' nan 'No pagó matrícula'] : Total valores unicos : 9
# --------------------------------------------------
# ESTU_PAGOMATRICULABECA : ['No' 'Si' nan] : Total valores unicos : 3
# --------------------------------------------------
# ESTU_PAGOMATRICULACREDITO : ['No' 'Si' nan] : Total valores unicos : 3
# --------------------------------------------------
# ESTU_HORASSEMANATRABAJA : ['Más de 30 horas' 'Entre 11 y 20 horas' 'Entre 21 y 30 horas' nan '0'
#  'Menos de 10 horas'] : Total valores unicos : 6
# --------------------------------------------------
# ESTU_GENERO--------- : ['M' 'F' nan] : Total valores unicos : 3
# --------------------------------------------------
# ESTU_PAGOMATRICULAPADRES : ['Si' 'No' nan] : Total valores unicos : 3
# --------------------------------------------------
# ESTU_ESTADOINVESTIGACION : ['PUBLICAR' 'NO SE COMPROBO IDENTIDAD DEL EXAMINADO'
#  'PRESENTE CON LECTURA TARDIA' 'VALIDEZ OFICINA JURÍDICA'] : Total valores unicos : 4
# --------------------------------------------------
# ESTU_PAGOMATRICULAPROPIO : ['Si' 'No' nan] : Total valores unicos : 3
# --------------------------------------------------
# FAMI_EDUCACIONPADRE- : ['Secundaria (Bachillerato) incompleta' 'Técnica o tecnológica completa'
#  nan 'Educación profesional completa' 'Postgrado' 'Primaria incompleta'
#  'Secundaria (Bachillerato) completa' 'No sabe' 'Primaria completa'
#  'No Aplica' 'Educación profesional incompleta'
#  'Técnica o tecnológica incompleta' 'Ninguno'] : Total valores unicos : 13
# --------------------------------------------------
# FAMI_TIENEAUTOMOVIL- : ['Si' 'No' nan] : Total valores unicos : 3
# --------------------------------------------------
# FAMI_TIENELAVADORA-- : ['Si' nan 'No'] : Total valores unicos : 3
# --------------------------------------------------
# FAMI_ESTRATOVIVIENDA : ['Estrato 3' nan 'Estrato 6' 'Estrato 2' 'Estrato 1' 'Sin Estrato'
#  'Estrato 4' 'Estrato 5'] : Total valores unicos : 8
# --------------------------------------------------
# FAMI_TIENECOMPUTADOR : ['Si' nan 'No'] : Total valores unicos : 3
# --------------------------------------------------
# FAMI_TIENEINTERNET-- : ['Si' nan 'No'] : Total valores unicos : 3
# --------------------------------------------------
# FAMI_EDUCACIONMADRE- : ['Secundaria (Bachillerato) incompleta' nan
#  'Educación profesional completa' 'Postgrado'
#  'Secundaria (Bachillerato) completa' 'Técnica o tecnológica completa'
#  'Primaria completa' 'Primaria incompleta'
#  'Técnica o tecnológica incompleta' 'Ninguno'
#  'Educación profesional incompleta' 'No Aplica' 'No sabe'] : Total valores unicos : 13
# --------------------------------------------------
# INST_ORIGEN--------- : ['NO OFICIAL - CORPORACIÓN' 'NO OFICIAL - FUNDACIÓN' 'OFICIAL NACIONAL'
#  'OFICIAL DEPARTAMENTAL' 'OFICIAL MUNICIPAL'] : Total valores unicos : 5
# --------------------------------------------------
# ESTU_VALORMATRICULAUNIVERSIDAD_ENCODED : [ 5  4  7  3  1  2  6 -1  0] : Total valores unicos : 9
# --------------------------------------------------
# ESTU_HORASSEMANATRABAJA_ENCODED : [ 4  2  3 -1  0  1] : Total valores unicos : 6
# --------------------------------------------------
# FAMI_ESTRATOVIVIENDA_ENCODED : [ 3 -1  6  2  1  0  4  5] : Total valores unicos : 8
# --------------------------------------------------
# FAMI_EDUCACIONPADRE_ENCODED : [ 3  6 -1  8  9  1  4  0  2  7  5] : Total valores unicos : 11
# --------------------------------------------------
# FAMI_EDUCACIONMADRE_ENCODED : [ 3 -1  8  9  4  6  2  1  5  0  7] : Total valores unicos : 11

# %%
# Horizontal bar plot for cateogorical features
for i in list(data.columns):
    if i in categorical_features or i in ordinal_features:
        print('\n------------------------------------\n')
        data.groupby(i)[target[0]].count().plot(kind = 'barh' , title = 'Distribution of ' + i)
        plt.show()
# Out:
# ------------------------------------
# ------------------------------------
# ------------------------------------
# ------------------------------------
# ------------------------------------
# ------------------------------------
# ------------------------------------
# ------------------------------------
# ------------------------------------
# ------------------------------------
# ------------------------------------
# ------------------------------------
# ------------------------------------
# ------------------------------------
# ------------------------------------
# ------------------------------------
# ------------------------------------
# ------------------------------------
# ------------------------------------
# ------------------------------------
# ------------------------------------

# %% [markdown]
# # **3. Ingeniería de características**
# En esta sección se aplican las transformaciones a las variables, así como la aplicación de diferentes técnicas para el mejoramiento del desempeño de los modelos

# %%
# Aplicar one hot encoding a las variables categóricas
numeric_scaler = MinMaxScaler()
cat_encoder = OrdinalEncoder()
# Definir una base con las variables que son categoricas pero no se necesitan hacer one hot encoding
categorical_no_encoding = ['ESTU_COD_RESIDE_DEPTO',
                             'ESTU_COD_DEPTO_PRESENTACION',
                             'INST_COD_INSTITUCION']
categorical_yes_encoding = [i for i in categorical_features if i not in categorical_no_encoding]
# Fit objects
#numeric_scaler.fit(data_1[numeric_features])
cat_encoder.fit(data[categorical_yes_encoding])
# Transformar la información
#aux_numeric = pd.DataFrame(numeric_scaler.transform(data_1[numeric_features]) , columns = data_1[numeric_features].columns.tolist())
#aux_categorical = pd.DataFrame.sparse.from_spmatrix(cat_encoder.transform(data[categorical_features]) , columns = cat_encoder.get_feature_names_out().tolist())
aux_categorical = pd.DataFrame(cat_encoder.transform(data[categorical_yes_encoding]) , columns = categorical_yes_encoding)
# Concatenar la información
data_2 = pd.concat([aux_categorical.reset_index(drop = True),
                    data[ordinal_features].reset_index(drop = True),
                    data[categorical_no_encoding].reset_index(drop = True),
                    data[target].reset_index(drop = True)] , axis = 1)
# Definir los tipos de datos para las variables
for i in data_2.columns.tolist():
    print('-' * 25)
    print(i)
    if i in numeric_features or i in target:
        data_2[i] = data_2[i].fillna(-1).astype(float)
        print('Variable' , i , 'converdita a float')
    if i in ordinal_features or i in categorical_features:
        data_2[i] = data_2[i].fillna(-1).astype(int)
        print('Variable' , i , 'convertida a int')
data_2
# Out:
# -------------------------
# INST_CARACTER_ACADEMICO
# Variable INST_CARACTER_ACADEMICO convertida a int
# -------------------------
# ESTU_METODO_PRGM
# Variable ESTU_METODO_PRGM convertida a int
# -------------------------
# ESTU_PAGOMATRICULABECA
# Variable ESTU_PAGOMATRICULABECA convertida a int
# -------------------------
# ESTU_PAGOMATRICULACREDITO
# Variable ESTU_PAGOMATRICULACREDITO convertida a int
# -------------------------
# ESTU_GENERO
# Variable ESTU_GENERO convertida a int
# -------------------------
# ESTU_PAGOMATRICULAPADRES
# Variable ESTU_PAGOMATRICULAPADRES convertida a int
# -------------------------
# ESTU_ESTADOINVESTIGACION
# Variable ESTU_ESTADOINVESTIGACION convertida a int
# -------------------------
# ESTU_PAGOMATRICULAPROPIO
# Variable ESTU_PAGOMATRICULAPROPIO convertida a int
# -------------------------
# FAMI_TIENEAUTOMOVIL
# Variable FAMI_TIENEAUTOMOVIL convertida a int
# -------------------------
# FAMI_TIENELAVADORA
# Variable FAMI_TIENELAVADORA convertida a int
# -------------------------
# FAMI_TIENECOMPUTADOR
# Variable FAMI_TIENECOMPUTADOR convertida a int
# -------------------------
# FAMI_TIENEINTERNET
# Variable FAMI_TIENEINTERNET convertida a int
# -------------------------
# INST_ORIGEN
# Variable INST_ORIGEN convertida a int
# -------------------------
# ESTU_VALORMATRICULAUNIVERSIDAD_ENCODED
# Variable ESTU_VALORMATRICULAUNIVERSIDAD_ENCODED convertida a int
# -------------------------
# ESTU_HORASSEMANATRABAJA_ENCODED
# Variable ESTU_HORASSEMANATRABAJA_ENCODED convertida a int
# -------------------------
# FAMI_ESTRATOVIVIENDA_ENCODED
# Variable FAMI_ESTRATOVIVIENDA_ENCODED convertida a int
# -------------------------
# FAMI_EDUCACIONPADRE_ENCODED
# Variable FAMI_EDUCACIONPADRE_ENCODED convertida a int
# -------------------------
# FAMI_EDUCACIONMADRE_ENCODED
# Variable FAMI_EDUCACIONMADRE_ENCODED convertida a int
# -------------------------
# ESTU_COD_RESIDE_DEPTO
# Variable ESTU_COD_RESIDE_DEPTO convertida a int
# -------------------------
# ESTU_COD_DEPTO_PRESENTACION
# Variable ESTU_COD_DEPTO_PRESENTACION convertida a int
# -------------------------
# INST_COD_INSTITUCION
# Variable INST_COD_INSTITUCION convertida a int
# -------------------------
# PUNTAJE_GLOBAL
# Variable PUNTAJE_GLOBAL converdita a float
# -------------------------
# MOD_RAZONA_CUANTITAT_PUNT
# Variable MOD_RAZONA_CUANTITAT_PUNT converdita a float
# -------------------------
# MOD_COMUNI_ESCRITA_PUNT
# Variable MOD_COMUNI_ESCRITA_PUNT converdita a float
# -------------------------
# MOD_INGLES_PUNT
# Variable MOD_INGLES_PUNT converdita a float
# -------------------------
# MOD_LECTURA_CRITICA_PUNT
# Variable MOD_LECTURA_CRITICA_PUNT converdita a float
# -------------------------
# MOD_COMPETEN_CIUDADA_PUNT
# Variable MOD_COMPETEN_CIUDADA_PUNT converdita a float
#        INST_CARACTER_ACADEMICO  ESTU_METODO_PRGM  ESTU_PAGOMATRICULABECA  \
# 0                            3                 2                       0
# 1                            3                 2                       1
# 2                            3                 2                       0
# 3                            3                 2                       0
# 4                            3                 2                       1
# ...                        ...               ...                     ...
# 61016                        3                 2                       0
# 61017                        1                 1                       1
# 61018                        1                 2                       0
# 61019                        1                 1                       0
# 61020                        1                 2                       0
#
#        ESTU_PAGOMATRICULACREDITO  ESTU_GENERO  ESTU_PAGOMATRICULAPADRES  \
# 0                              0            1                         1
# 1                              1            1                         0
# 2                              0            0                         1
# 3                              0            0                         1
# 4                              0            0                         1
# ...                          ...          ...                       ...
# 61016                          1            1                         1
# 61017                          1            0                         0
# 61018                          0            1                         1
# 61019                          0            0                         0
# 61020                          0            1                         0
#
#        ESTU_ESTADOINVESTIGACION  ESTU_PAGOMATRICULAPROPIO  \
# 0                             2                         1
# 1                             2                         0
# 2                             2                         1
# 3                             2                         0
# 4                             2                         0
# ...                         ...                       ...
# 61016                         2                         0
# 61017                         2                         1
# 61018                         2                         1
# 61019                         2                         1
# 61020                         2                         1
#
#        FAMI_TIENEAUTOMOVIL  FAMI_TIENELAVADORA  ...  \
# 0                        1                   1  ...
# 1                        0                   1  ...
# 2                        1                   1  ...
# 3                       -1                  -1  ...
# 4                        0                   1  ...
# ...                    ...                 ...  ...
# 61016                    0                   1  ...
# 61017                    0                   1  ...
# 61018                    1                   1  ...
# 61019                    0                   1  ...
# 61020                   -1                   0  ...
#
#        FAMI_EDUCACIONMADRE_ENCODED  ESTU_COD_RESIDE_DEPTO  \
# 0                                3                     76
# 1                                3                     66
# 2                                3                     11
# 3                               -1                      5
# 4                                8                     11
# ...                            ...                    ...
# 61016                            8                     11
# 61017                            0                     76
# 61018                            9                     41
# 61019                            1                     25
# 61020                            6                     11
#
#        ESTU_COD_DEPTO_PRESENTACION  INST_COD_INSTITUCION  PUNTAJE_GLOBAL  \
# 0                               76                  1805           180.2
# 1                               66                  2711           160.6
# 2                               11                  5802           147.2
# 3                                5                  2813           174.6
# 4                               11                  1813           211.8
# ...                            ...                   ...             ...
# 61016                           11                  1709           171.6
# 61017                           76                  2725           117.2
# 61018                           11                  2828           153.8
# 61019                           25                  2725           107.6
# 61020                           11                  9899           141.2
#
#        MOD_RAZONA_CUANTITAT_PUNT  MOD_COMUNI_ESCRITA_PUNT  MOD_INGLES_PUNT  \
# 0                          193.0                    153.0            195.0
# 1                          180.0                    146.0            170.0
# 2                          145.0                    140.0            127.0
# 3                          186.0                    148.0            214.0
# 4                          217.0                    199.0            209.0
# ...                          ...                      ...              ...
# 61016                      203.0                    128.0            186.0
# 61017                      137.0                      0.0            141.0
# 61018                      162.0                    133.0            168.0
# 61019                      107.0                    107.0            120.0
# 61020                      157.0                    133.0            169.0
#
#        MOD_LECTURA_CRITICA_PUNT  MOD_COMPETEN_CIUDADA_PUNT
# 0                         178.0                      182.0
# 1                         158.0                      149.0
# 2                         146.0                      178.0
# 3                         190.0                      135.0
# 4                         217.0                      217.0
# ...                         ...                        ...
# 61016                     189.0                      152.0
# 61017                     145.0                      163.0
# 61018                     128.0                      178.0
# 61019                      77.0                      127.0
# 61020                     133.0                      114.0
#
# [61021 rows x 27 columns]

# %% [markdown]
# # **2. Pipelines y Entrenamiento**

# %%
# Generate all posible combinations of steps
POSIBLE_VALUES = {'Imputation' : [SimpleImputer(strategy = 'mean'),
                                  KNNImputer()],
                  'Seleccion_Variables' : [SelectKBest(score_func=f_regression, k=10),
                                           SelectFromModel(estimator=AdaBoostRegressor()),
                                           VarianceThreshold(threshold=0.1),
                                           SelectKBest(score_func=mutual_info_regression, k=10),
                                          'passthrough'],
                 'Model' : [ExtraTreesRegressor(),
                            ExtraTreeRegressor(),
                            AdaBoostRegressor(),
                            XGBRegressor(),
                            BaggingRegressor(),
                            DecisionTreeRegressor(),
                            CatBoostRegressor(logging_level = 'Silent'),
                            LGBMRegressor(verbosity=-1),
                            HistGradientBoostingRegressor(),
                            MLPRegressor(hidden_layer_sizes = (512 , 10))]}

num_combinations = len(list(product(*POSIBLE_VALUES.values())))
all_combinations = [
    {key: value for key, value in zip(POSIBLE_VALUES.keys(), combo)}
    for combo in product(*POSIBLE_VALUES.values())]
print('Total Combinations:' , num_combinations)
# Out:
# Total Combinations: 100

# %% [markdown]
# ## **2.1 Puntaje Global**

# %%
aux_target = target[0]
aux_target
# Out:
# 'PUNTAJE_GLOBAL'

# %%
# Seleccionar la combinación de opciones usando algoritmos genéticos
X = data_2.drop(columns = target)
Y = data_2[aux_target]
print('X.shape' , X.shape)
print('Y.shape' , Y.shape)
# Definir la función de fitness
def evaluate(individual):

    # Crear pipeline con los componentes seleccionados
    steps = [
        ('imputer', POSIBLE_VALUES['Imputation'][individual[0]]),
        ('feature_selection' , POSIBLE_VALUES['Seleccion_Variables'][individual[1]]),
        ('regressor', POSIBLE_VALUES['Model'][individual[2]])
    ]
    
    pipeline = Pipeline(steps)
    
    # Entrenar y evaluar con MAE
    scores = cross_val_score(pipeline, X, Y, cv = 3, scoring='neg_mean_absolute_error')
    return np.mean(scores) * -1,

# Create the genetic algorithm's toolbox
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

toolbox = base.Toolbox()
toolbox.register("attr_imp", random.randint, 0, len(POSIBLE_VALUES['Imputation']) - 1)
toolbox.register("attr_feature_selector", random.randint, 0, len(POSIBLE_VALUES['Seleccion_Variables']) - 1)
toolbox.register("attr_model", random.randint, 0, len(POSIBLE_VALUES['Model']) - 1)

# Add the seed as a fifth attribute
toolbox.register("individual", tools.initCycle, creator.Individual,
                 (toolbox.attr_imp, toolbox.attr_feature_selector, toolbox.attr_model), n=1)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("evaluate", evaluate)
toolbox.register("mate", tools.cxTwoPoint)
toolbox.register("mutate", tools.mutUniformInt, low=[0]*3, up=[len(POSIBLE_VALUES['Imputation']) - 1,
                                                               len(POSIBLE_VALUES['Seleccion_Variables']) - 1,
                                                               len(POSIBLE_VALUES['Model']) - 1],
                indpb=0.2)
toolbox.register("select", tools.selTournament, tournsize=3)

# Run the genetic algorithm
def genetic_algorithm(n_gen=5, pop_size=10, cxpb=0.5, mutpb=0.2):
    pop = toolbox.population(n=pop_size)
    hof = tools.HallOfFame(1)
    stats = tools.Statistics(lambda ind: ind.fitness.values)
    stats.register("avg", np.mean)
    stats.register("std", np.std)
    stats.register("min", np.min)
    stats.register("max", np.max)

    pop, logbook = algorithms.eaSimple(pop, toolbox, cxpb=cxpb, mutpb=mutpb, ngen=n_gen,
                                       stats=stats, halloffame=hof, verbose=True)
    
    return pop, hof, logbook

# Execute the genetic algorithm
population, hall_of_fame, logbook = genetic_algorithm()

# Display the best individual found
best_individual = hall_of_fame[0]
print("Best individual is:", best_individual)
print('Best selection is:\n' ,
      POSIBLE_VALUES['Imputation'][best_individual[0]] , '\n' ,
      POSIBLE_VALUES['Seleccion_Variables'][best_individual[1]] , '\n' ,
      POSIBLE_VALUES['Model'][best_individual[2]])
print("Mejor MAE:", evaluate(best_individual))
# Out:
# X.shape (61021, 21)
# Y.shape (61021,)
# gen	nevals	avg    	std     	min    	max
# 0  	10    	16.2896	0.946368	15.3997	18.1848
# 1  	5     	15.9371	0.831266	15.3997	17.6584
# 2  	8     	15.5025	0.12435 	15.3997	15.7453
# 3  	4     	15.4193	0.0534484	15.3997	15.5789
# 4  	6     	15.3997	1.77636e-15	15.3997	15.3997
# 5  	8     	15.6481	0.745131   	15.3997	17.8835
# Best individual is: [1, 2, 6]
# Best selection is:
#  KNNImputer()
#  VarianceThreshold(threshold=0.1)
#  <catboost.core.CatBoostRegressor object at 0x0000015F85FD73D0>
# Mejor MAE: (15.399699030035789,)

# %%
# Crear un pipeline con la mejor seleccion  
mejor_pipeline = make_pipeline(POSIBLE_VALUES['Imputation'][best_individual[0]],
                          POSIBLE_VALUES['Seleccion_Variables'][best_individual[1]],
                          POSIBLE_VALUES['Model'][best_individual[2]])
mejor_pipeline.named_steps
# Out:
# {'knnimputer': KNNImputer(),
#  'variancethreshold': VarianceThreshold(threshold=0.1),
#  'catboostregressor': <catboost.core.CatBoostRegressor at 0x15f85fd73d0>}

# %%
# Definir los parámetros a optimizar
parametros_optimizar = {'knnimputer__n_neighbors' : [5 , 50, 100  , 500 , 1000],
                       'variancethreshold__threshold' : [0.1 , 0.25 , 0.5],
                       'catboostregressor__depth' : [6 , 8 , 10],
                       'catboostregressor__learning_rate' : [0.01 , 0.05 , 0.1]}

# Crear el grid search para realizar la búsqueda de hyperparametros
grid_search = GridSearchCV(mejor_pipeline,
                          param_grid = parametros_optimizar,
                          cv = 5,
                          verbose = 10,
                          scoring = 'neg_mean_absolute_error')
grid_search.fit(X , Y)
# Out:
# Fitting 5 folds for each of 135 candidates, totalling 675 fits
# [CV 1/5; 1/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=5, variancethreshold__threshold=0.1
# [CV 1/5; 1/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=5, variancethreshold__threshold=0.1;, score=-15.113 total time=   6.6s
# [CV 2/5; 1/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=5, variancethreshold__threshold=0.1
# [CV 2/5; 1/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=5, variancethreshold__threshold=0.1;, score=-15.247 total time=   6.3s
# [CV 3/5; 1/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=5, variancethreshold__threshold=0.1
# [CV 3/5; 1/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=5, variancethreshold__threshold=0.1;, score=-15.584 total time=   6.0s
# [CV 4/5; 1/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=5, variancethreshold__threshold=0.1
# [CV 4/5; 1/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=5, variancethreshold__threshold=0.1;, score=-15.374 total time=   6.8s
# [CV 5/5; 1/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=5, variancethreshold__threshold=0.1
# [CV 5/5; 1/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=5, variancethreshold__threshold=0.1;, score=-16.776 total time=   5.8s
# [CV 1/5; 2/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=5, variancethreshold__threshold=0.25
# [CV 1/5; 2/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=5, variancethreshold__threshold=0.25;, score=-15.234 total time=   6.4s
# [CV 2/5; 2/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=5, variancethreshold__threshold=0.25
# [CV 2/5; 2/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=5, variancethreshold__threshold=0.25;, score=-15.315 total time=   5.5s
# [CV 3/5; 2/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=5, variancethreshold__threshold=0.25
# [CV 3/5; 2/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=5, variancethreshold__threshold=0.25;, score=-15.677 total time=   5.9s
# [CV 4/5; 2/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=5, variancethreshold__threshold=0.25
# [CV 4/5; 2/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=5, variancethreshold__threshold=0.25;, score=-15.483 total time=   6.0s
# [CV 5/5; 2/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=5, variancethreshold__threshold=0.25
# [CV 5/5; 2/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=5, variancethreshold__threshold=0.25;, score=-16.900 total time=   5.6s
# [CV 1/5; 3/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=5, variancethreshold__threshold=0.5
# [CV 1/5; 3/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=5, variancethreshold__threshold=0.5;, score=-15.316 total time=   5.8s
# [CV 2/5; 3/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=5, variancethreshold__threshold=0.5
# [CV 2/5; 3/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=5, variancethreshold__threshold=0.5;, score=-15.381 total time=   5.0s
# [CV 3/5; 3/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=5, variancethreshold__threshold=0.5
# [CV 3/5; 3/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=5, variancethreshold__threshold=0.5;, score=-15.728 total time=   6.2s
# [CV 4/5; 3/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=5, variancethreshold__threshold=0.5
# [CV 4/5; 3/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=5, variancethreshold__threshold=0.5;, score=-15.550 total time=   5.7s
# [CV 5/5; 3/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=5, variancethreshold__threshold=0.5
# [CV 5/5; 3/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=5, variancethreshold__threshold=0.5;, score=-16.965 total time=   5.5s
# [CV 1/5; 4/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=50, variancethreshold__threshold=0.1
# [CV 1/5; 4/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=50, variancethreshold__threshold=0.1;, score=-15.113 total time=   6.1s
# [CV 2/5; 4/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=50, variancethreshold__threshold=0.1
# [CV 2/5; 4/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=50, variancethreshold__threshold=0.1;, score=-15.247 total time=   5.9s
# [CV 3/5; 4/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=50, variancethreshold__threshold=0.1
# [CV 3/5; 4/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=50, variancethreshold__threshold=0.1;, score=-15.584 total time=   6.7s
# [CV 4/5; 4/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=50, variancethreshold__threshold=0.1
# [CV 4/5; 4/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=50, variancethreshold__threshold=0.1;, score=-15.374 total time=   6.0s
# [CV 5/5; 4/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=50, variancethreshold__threshold=0.1
# [CV 5/5; 4/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=50, variancethreshold__threshold=0.1;, score=-16.776 total time=   5.9s
# [CV 1/5; 5/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=50, variancethreshold__threshold=0.25
# [CV 1/5; 5/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=50, variancethreshold__threshold=0.25;, score=-15.234 total time=   5.5s
# [CV 2/5; 5/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=50, variancethreshold__threshold=0.25
# [CV 2/5; 5/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=50, variancethreshold__threshold=0.25;, score=-15.315 total time=   5.6s
# [CV 3/5; 5/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=50, variancethreshold__threshold=0.25
# [CV 3/5; 5/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=50, variancethreshold__threshold=0.25;, score=-15.677 total time=   6.0s
# [CV 4/5; 5/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=50, variancethreshold__threshold=0.25
# [CV 4/5; 5/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=50, variancethreshold__threshold=0.25;, score=-15.483 total time=   5.9s
# [CV 5/5; 5/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=50, variancethreshold__threshold=0.25
# [CV 5/5; 5/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=50, variancethreshold__threshold=0.25;, score=-16.900 total time=   5.5s
# [CV 1/5; 6/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=50, variancethreshold__threshold=0.5
# [CV 1/5; 6/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=50, variancethreshold__threshold=0.5;, score=-15.316 total time=   5.5s
# [CV 2/5; 6/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=50, variancethreshold__threshold=0.5
# [CV 2/5; 6/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=50, variancethreshold__threshold=0.5;, score=-15.381 total time=   5.5s
# [CV 3/5; 6/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=50, variancethreshold__threshold=0.5
# [CV 3/5; 6/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=50, variancethreshold__threshold=0.5;, score=-15.728 total time=   5.6s
# [CV 4/5; 6/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=50, variancethreshold__threshold=0.5
# [CV 4/5; 6/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=50, variancethreshold__threshold=0.5;, score=-15.550 total time=   6.7s
# [CV 5/5; 6/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=50, variancethreshold__threshold=0.5
# [CV 5/5; 6/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=50, variancethreshold__threshold=0.5;, score=-16.965 total time=   5.5s
# [CV 1/5; 7/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=100, variancethreshold__threshold=0.1
# [CV 1/5; 7/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=100, variancethreshold__threshold=0.1;, score=-15.113 total time=   5.7s
# [CV 2/5; 7/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=100, variancethreshold__threshold=0.1
# [CV 2/5; 7/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=100, variancethreshold__threshold=0.1;, score=-15.247 total time=   6.5s
# [CV 3/5; 7/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=100, variancethreshold__threshold=0.1
# [CV 3/5; 7/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=100, variancethreshold__threshold=0.1;, score=-15.584 total time=   6.6s
# [CV 4/5; 7/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=100, variancethreshold__threshold=0.1
# [CV 4/5; 7/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=100, variancethreshold__threshold=0.1;, score=-15.374 total time=   6.0s
# [CV 5/5; 7/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=100, variancethreshold__threshold=0.1
# [CV 5/5; 7/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=100, variancethreshold__threshold=0.1;, score=-16.776 total time=   6.4s
# [CV 1/5; 8/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=100, variancethreshold__threshold=0.25
# [CV 1/5; 8/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=100, variancethreshold__threshold=0.25;, score=-15.234 total time=   5.7s
# [CV 2/5; 8/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=100, variancethreshold__threshold=0.25
# [CV 2/5; 8/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=100, variancethreshold__threshold=0.25;, score=-15.315 total time=   6.0s
# [CV 3/5; 8/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=100, variancethreshold__threshold=0.25
# [CV 3/5; 8/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=100, variancethreshold__threshold=0.25;, score=-15.677 total time=   5.5s
# [CV 4/5; 8/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=100, variancethreshold__threshold=0.25
# [CV 4/5; 8/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=100, variancethreshold__threshold=0.25;, score=-15.483 total time=   5.7s
# [CV 5/5; 8/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=100, variancethreshold__threshold=0.25
# [CV 5/5; 8/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=100, variancethreshold__threshold=0.25;, score=-16.900 total time=   6.3s
# [CV 1/5; 9/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=100, variancethreshold__threshold=0.5
# [CV 1/5; 9/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=100, variancethreshold__threshold=0.5;, score=-15.316 total time=   5.6s
# [CV 2/5; 9/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=100, variancethreshold__threshold=0.5
# [CV 2/5; 9/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=100, variancethreshold__threshold=0.5;, score=-15.381 total time=   5.1s
# [CV 3/5; 9/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=100, variancethreshold__threshold=0.5
# [CV 3/5; 9/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=100, variancethreshold__threshold=0.5;, score=-15.728 total time=   5.3s
# [CV 4/5; 9/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=100, variancethreshold__threshold=0.5
# [CV 4/5; 9/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=100, variancethreshold__threshold=0.5;, score=-15.550 total time=   5.2s
# [CV 5/5; 9/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=100, variancethreshold__threshold=0.5
# [CV 5/5; 9/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=100, variancethreshold__threshold=0.5;, score=-16.965 total time=   5.4s
# [CV 1/5; 10/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=500, variancethreshold__threshold=0.1
# [CV 1/5; 10/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=500, variancethreshold__threshold=0.1;, score=-15.113 total time=   6.0s
# [CV 2/5; 10/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=500, variancethreshold__threshold=0.1
# [CV 2/5; 10/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=500, variancethreshold__threshold=0.1;, score=-15.247 total time=   7.0s
# [CV 3/5; 10/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=500, variancethreshold__threshold=0.1
# [CV 3/5; 10/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=500, variancethreshold__threshold=0.1;, score=-15.584 total time=   6.3s
# [CV 4/5; 10/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=500, variancethreshold__threshold=0.1
# [CV 4/5; 10/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=500, variancethreshold__threshold=0.1;, score=-15.374 total time=   6.1s
# [CV 5/5; 10/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=500, variancethreshold__threshold=0.1
# [CV 5/5; 10/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=500, variancethreshold__threshold=0.1;, score=-16.776 total time=   6.6s
# [CV 1/5; 11/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=500, variancethreshold__threshold=0.25
# [CV 1/5; 11/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=500, variancethreshold__threshold=0.25;, score=-15.234 total time=   6.2s
# [CV 2/5; 11/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=500, variancethreshold__threshold=0.25
# [CV 2/5; 11/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=500, variancethreshold__threshold=0.25;, score=-15.315 total time=   5.8s
# [CV 3/5; 11/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=500, variancethreshold__threshold=0.25
# [CV 3/5; 11/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=500, variancethreshold__threshold=0.25;, score=-15.677 total time=   5.7s
# [CV 4/5; 11/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=500, variancethreshold__threshold=0.25
# [CV 4/5; 11/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=500, variancethreshold__threshold=0.25;, score=-15.483 total time=   6.3s
# [CV 5/5; 11/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=500, variancethreshold__threshold=0.25
# [CV 5/5; 11/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=500, variancethreshold__threshold=0.25;, score=-16.900 total time=   6.4s
# [CV 1/5; 12/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=500, variancethreshold__threshold=0.5
# [CV 1/5; 12/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=500, variancethreshold__threshold=0.5;, score=-15.316 total time=   5.0s
# [CV 2/5; 12/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=500, variancethreshold__threshold=0.5
# [CV 2/5; 12/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=500, variancethreshold__threshold=0.5;, score=-15.381 total time=   5.2s
# [CV 3/5; 12/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=500, variancethreshold__threshold=0.5
# [CV 3/5; 12/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=500, variancethreshold__threshold=0.5;, score=-15.728 total time=   5.4s
# [CV 4/5; 12/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=500, variancethreshold__threshold=0.5
# [CV 4/5; 12/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=500, variancethreshold__threshold=0.5;, score=-15.550 total time=   5.4s
# [CV 5/5; 12/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=500, variancethreshold__threshold=0.5
# [CV 5/5; 12/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=500, variancethreshold__threshold=0.5;, score=-16.965 total time=   5.6s
# [CV 1/5; 13/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.1
# [CV 1/5; 13/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.1;, score=-15.113 total time=   6.2s
# [CV 2/5; 13/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.1
# [CV 2/5; 13/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.1;, score=-15.247 total time=   5.7s
# [CV 3/5; 13/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.1
# [CV 3/5; 13/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.1;, score=-15.584 total time=   8.1s
# [CV 4/5; 13/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.1
# [CV 4/5; 13/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.1;, score=-15.374 total time=   6.3s
# [CV 5/5; 13/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.1
# [CV 5/5; 13/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.1;, score=-16.776 total time=   5.7s
# [CV 1/5; 14/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.25
# [CV 1/5; 14/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.25;, score=-15.234 total time=   5.8s
# [CV 2/5; 14/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.25
# [CV 2/5; 14/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.25;, score=-15.315 total time=   6.4s
# [CV 3/5; 14/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.25
# [CV 3/5; 14/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.25;, score=-15.677 total time=   6.2s
# [CV 4/5; 14/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.25
# [CV 4/5; 14/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.25;, score=-15.483 total time=   5.8s
# [CV 5/5; 14/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.25
# [CV 5/5; 14/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.25;, score=-16.900 total time=   6.3s
# [CV 1/5; 15/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.5
# [CV 1/5; 15/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.5;, score=-15.316 total time=   5.5s
# [CV 2/5; 15/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.5
# [CV 2/5; 15/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.5;, score=-15.381 total time=   5.4s
# [CV 3/5; 15/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.5
# [CV 3/5; 15/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.5;, score=-15.728 total time=   5.5s
# [CV 4/5; 15/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.5
# [CV 4/5; 15/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.5;, score=-15.550 total time=   5.2s
# [CV 5/5; 15/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.5
# [CV 5/5; 15/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.01, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.5;, score=-16.965 total time=   5.5s
# [CV 1/5; 16/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=5, variancethreshold__threshold=0.1
# [CV 1/5; 16/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=5, variancethreshold__threshold=0.1;, score=-14.840 total time=   6.8s
# [CV 2/5; 16/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=5, variancethreshold__threshold=0.1
# [CV 2/5; 16/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=5, variancethreshold__threshold=0.1;, score=-14.973 total time=   6.5s
# [CV 3/5; 16/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=5, variancethreshold__threshold=0.1
# [CV 3/5; 16/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=5, variancethreshold__threshold=0.1;, score=-15.276 total time=   5.5s
# [CV 4/5; 16/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=5, variancethreshold__threshold=0.1
# [CV 4/5; 16/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=5, variancethreshold__threshold=0.1;, score=-15.110 total time=   7.1s
# [CV 5/5; 16/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=5, variancethreshold__threshold=0.1
# [CV 5/5; 16/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=5, variancethreshold__threshold=0.1;, score=-16.544 total time=   6.3s
# [CV 1/5; 17/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=5, variancethreshold__threshold=0.25
# [CV 1/5; 17/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=5, variancethreshold__threshold=0.25;, score=-14.988 total time=   5.4s
# [CV 2/5; 17/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=5, variancethreshold__threshold=0.25
# [CV 2/5; 17/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=5, variancethreshold__threshold=0.25;, score=-15.050 total time=   5.6s
# [CV 3/5; 17/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=5, variancethreshold__threshold=0.25
# [CV 3/5; 17/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=5, variancethreshold__threshold=0.25;, score=-15.395 total time=   5.9s
# [CV 4/5; 17/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=5, variancethreshold__threshold=0.25
# [CV 4/5; 17/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=5, variancethreshold__threshold=0.25;, score=-15.231 total time=   6.2s
# [CV 5/5; 17/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=5, variancethreshold__threshold=0.25
# [CV 5/5; 17/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=5, variancethreshold__threshold=0.25;, score=-16.690 total time=   6.3s
# [CV 1/5; 18/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=5, variancethreshold__threshold=0.5
# [CV 1/5; 18/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=5, variancethreshold__threshold=0.5;, score=-15.068 total time=   5.5s
# [CV 2/5; 18/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=5, variancethreshold__threshold=0.5
# [CV 2/5; 18/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=5, variancethreshold__threshold=0.5;, score=-15.145 total time=   6.0s
# [CV 3/5; 18/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=5, variancethreshold__threshold=0.5
# [CV 3/5; 18/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=5, variancethreshold__threshold=0.5;, score=-15.483 total time=   5.2s
# [CV 4/5; 18/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=5, variancethreshold__threshold=0.5
# [CV 4/5; 18/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=5, variancethreshold__threshold=0.5;, score=-15.339 total time=   5.7s
# [CV 5/5; 18/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=5, variancethreshold__threshold=0.5
# [CV 5/5; 18/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=5, variancethreshold__threshold=0.5;, score=-16.779 total time=   5.3s
# [CV 1/5; 19/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=50, variancethreshold__threshold=0.1
# [CV 1/5; 19/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=50, variancethreshold__threshold=0.1;, score=-14.840 total time=   6.6s
# [CV 2/5; 19/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=50, variancethreshold__threshold=0.1
# [CV 2/5; 19/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=50, variancethreshold__threshold=0.1;, score=-14.973 total time=   6.4s
# [CV 3/5; 19/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=50, variancethreshold__threshold=0.1
# [CV 3/5; 19/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=50, variancethreshold__threshold=0.1;, score=-15.276 total time=   6.3s
# [CV 4/5; 19/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=50, variancethreshold__threshold=0.1
# [CV 4/5; 19/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=50, variancethreshold__threshold=0.1;, score=-15.110 total time=   6.3s
# [CV 5/5; 19/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=50, variancethreshold__threshold=0.1
# [CV 5/5; 19/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=50, variancethreshold__threshold=0.1;, score=-16.544 total time=   5.8s
# [CV 1/5; 20/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=50, variancethreshold__threshold=0.25
# [CV 1/5; 20/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=50, variancethreshold__threshold=0.25;, score=-14.988 total time=   6.4s
# [CV 2/5; 20/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=50, variancethreshold__threshold=0.25
# [CV 2/5; 20/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=50, variancethreshold__threshold=0.25;, score=-15.050 total time=   6.0s
# [CV 3/5; 20/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=50, variancethreshold__threshold=0.25
# [CV 3/5; 20/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=50, variancethreshold__threshold=0.25;, score=-15.395 total time=   5.4s
# [CV 4/5; 20/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=50, variancethreshold__threshold=0.25
# [CV 4/5; 20/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=50, variancethreshold__threshold=0.25;, score=-15.231 total time=   5.8s
# [CV 5/5; 20/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=50, variancethreshold__threshold=0.25
# [CV 5/5; 20/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=50, variancethreshold__threshold=0.25;, score=-16.690 total time=   5.5s
# [CV 1/5; 21/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=50, variancethreshold__threshold=0.5
# [CV 1/5; 21/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=50, variancethreshold__threshold=0.5;, score=-15.068 total time=   5.3s
# [CV 2/5; 21/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=50, variancethreshold__threshold=0.5
# [CV 2/5; 21/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=50, variancethreshold__threshold=0.5;, score=-15.145 total time=   5.6s
# [CV 3/5; 21/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=50, variancethreshold__threshold=0.5
# [CV 3/5; 21/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=50, variancethreshold__threshold=0.5;, score=-15.483 total time=   5.6s
# [CV 4/5; 21/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=50, variancethreshold__threshold=0.5
# [CV 4/5; 21/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=50, variancethreshold__threshold=0.5;, score=-15.339 total time=   5.1s
# [CV 5/5; 21/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=50, variancethreshold__threshold=0.5
# [CV 5/5; 21/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=50, variancethreshold__threshold=0.5;, score=-16.779 total time=   6.1s
# [CV 1/5; 22/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=100, variancethreshold__threshold=0.1
# [CV 1/5; 22/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=100, variancethreshold__threshold=0.1;, score=-14.840 total time=   5.9s
# [CV 2/5; 22/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=100, variancethreshold__threshold=0.1
# [CV 2/5; 22/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=100, variancethreshold__threshold=0.1;, score=-14.973 total time=   6.3s
# [CV 3/5; 22/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=100, variancethreshold__threshold=0.1
# [CV 3/5; 22/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=100, variancethreshold__threshold=0.1;, score=-15.276 total time=   5.6s
# [CV 4/5; 22/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=100, variancethreshold__threshold=0.1
# [CV 4/5; 22/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=100, variancethreshold__threshold=0.1;, score=-15.110 total time=   6.5s
# [CV 5/5; 22/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=100, variancethreshold__threshold=0.1
# [CV 5/5; 22/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=100, variancethreshold__threshold=0.1;, score=-16.544 total time=   5.6s
# [CV 1/5; 23/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=100, variancethreshold__threshold=0.25
# [CV 1/5; 23/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=100, variancethreshold__threshold=0.25;, score=-14.988 total time=   5.6s
# [CV 2/5; 23/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=100, variancethreshold__threshold=0.25
# [CV 2/5; 23/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=100, variancethreshold__threshold=0.25;, score=-15.050 total time=   6.4s
# [CV 3/5; 23/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=100, variancethreshold__threshold=0.25
# [CV 3/5; 23/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=100, variancethreshold__threshold=0.25;, score=-15.395 total time=   5.4s
# [CV 4/5; 23/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=100, variancethreshold__threshold=0.25
# [CV 4/5; 23/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=100, variancethreshold__threshold=0.25;, score=-15.231 total time=   5.7s
# [CV 5/5; 23/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=100, variancethreshold__threshold=0.25
# [CV 5/5; 23/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=100, variancethreshold__threshold=0.25;, score=-16.690 total time=   5.9s
# [CV 1/5; 24/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=100, variancethreshold__threshold=0.5
# [CV 1/5; 24/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=100, variancethreshold__threshold=0.5;, score=-15.068 total time=   5.3s
# [CV 2/5; 24/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=100, variancethreshold__threshold=0.5
# [CV 2/5; 24/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=100, variancethreshold__threshold=0.5;, score=-15.145 total time=   6.2s
# [CV 3/5; 24/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=100, variancethreshold__threshold=0.5
# [CV 3/5; 24/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=100, variancethreshold__threshold=0.5;, score=-15.483 total time=   5.3s
# [CV 4/5; 24/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=100, variancethreshold__threshold=0.5
# [CV 4/5; 24/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=100, variancethreshold__threshold=0.5;, score=-15.339 total time=   5.4s
# [CV 5/5; 24/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=100, variancethreshold__threshold=0.5
# [CV 5/5; 24/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=100, variancethreshold__threshold=0.5;, score=-16.779 total time=   5.0s
# [CV 1/5; 25/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=500, variancethreshold__threshold=0.1
# [CV 1/5; 25/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=500, variancethreshold__threshold=0.1;, score=-14.840 total time=   6.9s
# [CV 2/5; 25/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=500, variancethreshold__threshold=0.1
# [CV 2/5; 25/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=500, variancethreshold__threshold=0.1;, score=-14.973 total time=   5.8s
# [CV 3/5; 25/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=500, variancethreshold__threshold=0.1
# [CV 3/5; 25/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=500, variancethreshold__threshold=0.1;, score=-15.276 total time=   6.0s
# [CV 4/5; 25/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=500, variancethreshold__threshold=0.1
# [CV 4/5; 25/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=500, variancethreshold__threshold=0.1;, score=-15.110 total time=   6.2s
# [CV 5/5; 25/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=500, variancethreshold__threshold=0.1
# [CV 5/5; 25/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=500, variancethreshold__threshold=0.1;, score=-16.544 total time=   5.8s
# [CV 1/5; 26/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=500, variancethreshold__threshold=0.25
# [CV 1/5; 26/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=500, variancethreshold__threshold=0.25;, score=-14.988 total time=   6.9s
# [CV 2/5; 26/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=500, variancethreshold__threshold=0.25
# [CV 2/5; 26/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=500, variancethreshold__threshold=0.25;, score=-15.050 total time=   5.9s
# [CV 3/5; 26/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=500, variancethreshold__threshold=0.25
# [CV 3/5; 26/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=500, variancethreshold__threshold=0.25;, score=-15.395 total time=   5.8s
# [CV 4/5; 26/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=500, variancethreshold__threshold=0.25
# [CV 4/5; 26/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=500, variancethreshold__threshold=0.25;, score=-15.231 total time=   6.3s
# [CV 5/5; 26/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=500, variancethreshold__threshold=0.25
# [CV 5/5; 26/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=500, variancethreshold__threshold=0.25;, score=-16.690 total time=   5.6s
# [CV 1/5; 27/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=500, variancethreshold__threshold=0.5
# [CV 1/5; 27/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=500, variancethreshold__threshold=0.5;, score=-15.068 total time=   5.8s
# [CV 2/5; 27/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=500, variancethreshold__threshold=0.5
# [CV 2/5; 27/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=500, variancethreshold__threshold=0.5;, score=-15.145 total time=   5.2s
# [CV 3/5; 27/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=500, variancethreshold__threshold=0.5
# [CV 3/5; 27/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=500, variancethreshold__threshold=0.5;, score=-15.483 total time=   5.5s
# [CV 4/5; 27/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=500, variancethreshold__threshold=0.5
# [CV 4/5; 27/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=500, variancethreshold__threshold=0.5;, score=-15.339 total time=   5.3s
# [CV 5/5; 27/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=500, variancethreshold__threshold=0.5
# [CV 5/5; 27/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=500, variancethreshold__threshold=0.5;, score=-16.779 total time=   6.0s
# [CV 1/5; 28/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.1
# [CV 1/5; 28/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.1;, score=-14.840 total time=   5.8s
# [CV 2/5; 28/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.1
# [CV 2/5; 28/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.1;, score=-14.973 total time=   6.2s
# [CV 3/5; 28/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.1
# [CV 3/5; 28/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.1;, score=-15.276 total time=   5.8s
# [CV 4/5; 28/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.1
# [CV 4/5; 28/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.1;, score=-15.110 total time=   6.4s
# [CV 5/5; 28/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.1
# [CV 5/5; 28/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.1;, score=-16.544 total time=   5.8s
# [CV 1/5; 29/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.25
# [CV 1/5; 29/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.25;, score=-14.988 total time=   5.6s
# [CV 2/5; 29/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.25
# [CV 2/5; 29/135] END catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.25;, score=-15.050 total time=   5.7s
# [CV 3/5; 29/135] START catboostregressor__depth=6, catboostregressor__learning_rate=0.05, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.25
# ...
# [CV 1/5; 127/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=100, variancethreshold__threshold=0.1;, score=-15.297 total time=  16.4s
# [CV 2/5; 127/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=100, variancethreshold__threshold=0.1
# [CV 2/5; 127/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=100, variancethreshold__threshold=0.1;, score=-15.477 total time=  15.6s
# [CV 3/5; 127/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=100, variancethreshold__threshold=0.1
# [CV 3/5; 127/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=100, variancethreshold__threshold=0.1;, score=-15.741 total time=  15.4s
# [CV 4/5; 127/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=100, variancethreshold__threshold=0.1
# [CV 4/5; 127/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=100, variancethreshold__threshold=0.1;, score=-15.612 total time=  15.4s
# [CV 5/5; 127/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=100, variancethreshold__threshold=0.1
# [CV 5/5; 127/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=100, variancethreshold__threshold=0.1;, score=-17.123 total time=  16.2s
# [CV 1/5; 128/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=100, variancethreshold__threshold=0.25
# [CV 1/5; 128/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=100, variancethreshold__threshold=0.25;, score=-15.496 total time=  15.5s
# [CV 2/5; 128/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=100, variancethreshold__threshold=0.25
# [CV 2/5; 128/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=100, variancethreshold__threshold=0.25;, score=-15.575 total time=  15.1s
# [CV 3/5; 128/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=100, variancethreshold__threshold=0.25
# [CV 3/5; 128/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=100, variancethreshold__threshold=0.25;, score=-15.842 total time=  15.2s
# [CV 4/5; 128/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=100, variancethreshold__threshold=0.25
# [CV 4/5; 128/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=100, variancethreshold__threshold=0.25;, score=-15.746 total time=  14.9s
# [CV 5/5; 128/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=100, variancethreshold__threshold=0.25
# [CV 5/5; 128/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=100, variancethreshold__threshold=0.25;, score=-17.201 total time=  16.4s
# [CV 1/5; 129/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=100, variancethreshold__threshold=0.5
# [CV 1/5; 129/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=100, variancethreshold__threshold=0.5;, score=-15.562 total time=  13.3s
# [CV 2/5; 129/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=100, variancethreshold__threshold=0.5
# [CV 2/5; 129/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=100, variancethreshold__threshold=0.5;, score=-15.530 total time=  13.4s
# [CV 3/5; 129/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=100, variancethreshold__threshold=0.5
# [CV 3/5; 129/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=100, variancethreshold__threshold=0.5;, score=-15.925 total time=  13.8s
# [CV 4/5; 129/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=100, variancethreshold__threshold=0.5
# [CV 4/5; 129/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=100, variancethreshold__threshold=0.5;, score=-15.768 total time=  13.0s
# [CV 5/5; 129/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=100, variancethreshold__threshold=0.5
# [CV 5/5; 129/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=100, variancethreshold__threshold=0.5;, score=-17.296 total time=  12.9s
# [CV 1/5; 130/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=500, variancethreshold__threshold=0.1
# [CV 1/5; 130/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=500, variancethreshold__threshold=0.1;, score=-15.297 total time=  16.3s
# [CV 2/5; 130/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=500, variancethreshold__threshold=0.1
# [CV 2/5; 130/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=500, variancethreshold__threshold=0.1;, score=-15.477 total time=  15.4s
# [CV 3/5; 130/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=500, variancethreshold__threshold=0.1
# [CV 3/5; 130/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=500, variancethreshold__threshold=0.1;, score=-15.741 total time=  15.8s
# [CV 4/5; 130/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=500, variancethreshold__threshold=0.1
# [CV 4/5; 130/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=500, variancethreshold__threshold=0.1;, score=-15.612 total time=  16.9s
# [CV 5/5; 130/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=500, variancethreshold__threshold=0.1
# [CV 5/5; 130/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=500, variancethreshold__threshold=0.1;, score=-17.123 total time=  15.5s
# [CV 1/5; 131/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=500, variancethreshold__threshold=0.25
# [CV 1/5; 131/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=500, variancethreshold__threshold=0.25;, score=-15.496 total time=  15.9s
# [CV 2/5; 131/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=500, variancethreshold__threshold=0.25
# [CV 2/5; 131/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=500, variancethreshold__threshold=0.25;, score=-15.575 total time=  14.5s
# [CV 3/5; 131/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=500, variancethreshold__threshold=0.25
# [CV 3/5; 131/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=500, variancethreshold__threshold=0.25;, score=-15.842 total time=  15.1s
# [CV 4/5; 131/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=500, variancethreshold__threshold=0.25
# [CV 4/5; 131/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=500, variancethreshold__threshold=0.25;, score=-15.746 total time=  15.0s
# [CV 5/5; 131/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=500, variancethreshold__threshold=0.25
# [CV 5/5; 131/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=500, variancethreshold__threshold=0.25;, score=-17.201 total time=  14.4s
# [CV 1/5; 132/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=500, variancethreshold__threshold=0.5
# [CV 1/5; 132/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=500, variancethreshold__threshold=0.5;, score=-15.562 total time=  13.5s
# [CV 2/5; 132/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=500, variancethreshold__threshold=0.5
# [CV 2/5; 132/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=500, variancethreshold__threshold=0.5;, score=-15.530 total time=  13.7s
# [CV 3/5; 132/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=500, variancethreshold__threshold=0.5
# [CV 3/5; 132/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=500, variancethreshold__threshold=0.5;, score=-15.925 total time=  13.2s
# [CV 4/5; 132/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=500, variancethreshold__threshold=0.5
# [CV 4/5; 132/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=500, variancethreshold__threshold=0.5;, score=-15.768 total time=  12.9s
# [CV 5/5; 132/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=500, variancethreshold__threshold=0.5
# [CV 5/5; 132/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=500, variancethreshold__threshold=0.5;, score=-17.296 total time=  13.4s
# [CV 1/5; 133/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.1
# [CV 1/5; 133/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.1;, score=-15.297 total time=  17.8s
# [CV 2/5; 133/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.1
# [CV 2/5; 133/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.1;, score=-15.477 total time=  15.5s
# [CV 3/5; 133/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.1
# [CV 3/5; 133/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.1;, score=-15.741 total time=  15.2s
# [CV 4/5; 133/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.1
# [CV 4/5; 133/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.1;, score=-15.612 total time=  16.0s
# [CV 5/5; 133/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.1
# [CV 5/5; 133/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.1;, score=-17.123 total time=  15.2s
# [CV 1/5; 134/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.25
# [CV 1/5; 134/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.25;, score=-15.496 total time=  15.0s
# [CV 2/5; 134/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.25
# [CV 2/5; 134/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.25;, score=-15.575 total time=  14.8s
# [CV 3/5; 134/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.25
# [CV 3/5; 134/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.25;, score=-15.842 total time=  14.4s
# [CV 4/5; 134/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.25
# [CV 4/5; 134/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.25;, score=-15.746 total time=  14.5s
# [CV 5/5; 134/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.25
# [CV 5/5; 134/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.25;, score=-17.201 total time=  15.6s
# [CV 1/5; 135/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.5
# [CV 1/5; 135/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.5;, score=-15.562 total time=  13.4s
# [CV 2/5; 135/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.5
# [CV 2/5; 135/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.5;, score=-15.530 total time=  13.4s
# [CV 3/5; 135/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.5
# [CV 3/5; 135/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.5;, score=-15.925 total time=  13.8s
# [CV 4/5; 135/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.5
# [CV 4/5; 135/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.5;, score=-15.768 total time=  13.5s
# [CV 5/5; 135/135] START catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.5
# [CV 5/5; 135/135] END catboostregressor__depth=10, catboostregressor__learning_rate=0.1, knnimputer__n_neighbors=1000, variancethreshold__threshold=0.5;, score=-17.296 total time=  12.9s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('knnimputer', KNNImputer()),
#                                        ('variancethreshold',
#                                         VarianceThreshold(threshold=0.1)),
#                                        ('catboostregressor',
#                                         <catboost.core.CatBoostRegressor object at 0x0000015F85FD73D0>)]),
#              param_grid={'catboostregressor__depth': [6, 8, 10],
#                          'catboostregressor__learning_rate': [0.01, 0.05, 0.1],
#                          'knnimputer__n_neighbors': [5, 50, 100, 500, 1000],
#                          'variancethreshold__threshold': [0.1, 0.25, 0.5]},
#              scoring='neg_mean_absolute_error', verbose=10)

# %%
# Mostrar los resultados
print('Mejor modelo' , grid_search.best_estimator_)
print('Mejores parametros' , grid_search.best_params_)
print('Mejor MAE' , grid_search.best_score_)
pd.DataFrame(grid_search.cv_results_)
# Out:
# Mejor modelo Pipeline(steps=[('knnimputer', KNNImputer()),
#                 ('variancethreshold', VarianceThreshold(threshold=0.1)),
#                 ('catboostregressor',
#                  <catboost.core.CatBoostRegressor object at 0x000001615D559890>)])
# Mejores parametros {'catboostregressor__depth': 6, 'catboostregressor__learning_rate': 0.05, 'knnimputer__n_neighbors': 5, 'variancethreshold__threshold': 0.1}
# Mejor MAE -15.348889629862384
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         6.390683      0.399109         0.010373        0.000489
# 1         5.969015      0.339674         0.009768        0.000396
# 2         5.728781      0.377688         0.009976        0.000631
# 3         6.221037      0.296144         0.009966        0.000015
# 4         5.795693      0.204670         0.009878        0.000492
# ..             ...           ...              ...             ...
# 130      15.044526      0.532818         0.033903        0.002525
# 131      13.415754      0.266725         0.034705        0.005113
# 132      16.008713      0.987762         0.035513        0.006479
# 133      14.930365      0.417939         0.032530        0.002522
# 134      13.483044      0.279344         0.033404        0.002533
#
#     param_catboostregressor__depth param_catboostregressor__learning_rate  \
# 0                                6                                   0.01
# 1                                6                                   0.01
# 2                                6                                   0.01
# 3                                6                                   0.01
# 4                                6                                   0.01
# ..                             ...                                    ...
# 130                             10                                    0.1
# 131                             10                                    0.1
# 132                             10                                    0.1
# 133                             10                                    0.1
# 134                             10                                    0.1
#
#     param_knnimputer__n_neighbors param_variancethreshold__threshold  \
# 0                               5                                0.1
# 1                               5                               0.25
# 2                               5                                0.5
# 3                              50                                0.1
# 4                              50                               0.25
# ..                            ...                                ...
# 130                           500                               0.25
# 131                           500                                0.5
# 132                          1000                                0.1
# 133                          1000                               0.25
# 134                          1000                                0.5
#
#                                                 params  split0_test_score  \
# 0    {'catboostregressor__depth': 6, 'catboostregre...         -15.113427
# 1    {'catboostregressor__depth': 6, 'catboostregre...         -15.233876
# 2    {'catboostregressor__depth': 6, 'catboostregre...         -15.315601
# 3    {'catboostregressor__depth': 6, 'catboostregre...         -15.113427
# 4    {'catboostregressor__depth': 6, 'catboostregre...         -15.233876
# ..                                                 ...                ...
# 130  {'catboostregressor__depth': 10, 'catboostregr...         -15.495562
# 131  {'catboostregressor__depth': 10, 'catboostregr...         -15.562067
# 132  {'catboostregressor__depth': 10, 'catboostregr...         -15.297258
# 133  {'catboostregressor__depth': 10, 'catboostregr...         -15.495562
# 134  {'catboostregressor__depth': 10, 'catboostregr...         -15.562067
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 0           -15.247201         -15.583669         -15.373529
# 1           -15.314958         -15.677231         -15.483367
# 2           -15.380647         -15.727659         -15.550064
# 3           -15.247201         -15.583669         -15.373529
# 4           -15.314958         -15.677231         -15.483367
# ..                 ...                ...                ...
# 130         -15.574677         -15.841686         -15.746318
# 131         -15.529642         -15.925487         -15.767554
# 132         -15.477398         -15.741487         -15.611781
# 133         -15.574677         -15.841686         -15.746318
# 134         -15.529642         -15.925487         -15.767554
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -16.776431       -15.618851        0.599164               66
# 1           -16.900291       -15.721945        0.608485              101
# 2           -16.964957       -15.787786        0.605736              116
# 3           -16.776431       -15.618851        0.599164               66
# 4           -16.900291       -15.721945        0.608485              101
# ..                 ...              ...             ...              ...
# 130         -17.200818       -15.971812        0.626541              126
# 131         -17.295858       -16.016121        0.655828              131
# 132         -17.123109       -15.850206        0.653251              121
# 133         -17.200818       -15.971812        0.626541              126
# 134         -17.295858       -16.016121        0.655828              131
#
# [135 rows x 17 columns]

# %%
# Guardar resultados
pd.DataFrame(grid_search.cv_results_).to_excel(r'..\results\Resultados_Grid_Search_V20240822.xlsx')

# Guardar el modelo optimizado
# Exportar el categorical encoder
with open(r'..\models\Pipeline_V20240822.pkl' , 'wb') as file:
    joblib.dump(grid_search , file)
print('Archivo Generado -->' , str(grid_search) , 'en ../models/Pipeline_V20240822.pkl')
# Out:
# Archivo Generado --> GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('knnimputer', KNNImputer()),
#                                        ('variancethreshold',
#                                         VarianceThreshold(threshold=0.1)),
#                                        ('catboostregressor',
#                                         <catboost.core.CatBoostRegressor object at 0x0000015F85FD73D0>)]),
#              param_grid={'catboostregressor__depth': [6, 8, 10],
#                          'catboostregressor__learning_rate': [0.01, 0.05, 0.1],
#                          'knnimputer__n_neighbors': [5, 50, 100, 500, 1000],
#                          'variancethreshold__threshold': [0.1, 0.25, 0.5]},
#              scoring='neg_mean_absolute_error', verbose=10) en ../models/Pipeline_V20240822.pkl

# %% [markdown]
# # **3. Importancia de Variables y Análisis de Factores**

# %%
# Obtener el mejor modelo del grid search
mejor_modelo = grid_search.best_estimator_
feature_names = X.columns

# Aplicar las transformaciones sin el modelo final
X_transformed = mejor_modelo[:-1].transform(X)

# Filtrar los nombres de las características que no fueron eliminadas por VarianceThreshold
mask = mejor_modelo.named_steps['variancethreshold'].get_support()
selected_features = feature_names[mask].tolist()

# Ahora selected_features contiene los nombres de las variables que se utilizan en CatBoost
print('Variable Seleccionadas:', selected_features)
# Out:
# Variable Seleccionadas: ['INST_CARACTER_ACADEMICO', 'ESTU_METODO_PRGM', 'ESTU_PAGOMATRICULABECA', 'ESTU_PAGOMATRICULACREDITO', 'ESTU_GENERO', 'ESTU_PAGOMATRICULAPADRES', 'ESTU_PAGOMATRICULAPROPIO', 'FAMI_TIENEAUTOMOVIL', 'FAMI_TIENELAVADORA', 'FAMI_TIENECOMPUTADOR', 'FAMI_TIENEINTERNET', 'INST_ORIGEN', 'ESTU_VALORMATRICULAUNIVERSIDAD_ENCODED', 'ESTU_HORASSEMANATRABAJA_ENCODED', 'FAMI_ESTRATOVIVIENDA_ENCODED', 'FAMI_EDUCACIONPADRE_ENCODED', 'FAMI_EDUCACIONMADRE_ENCODED', 'ESTU_COD_RESIDE_DEPTO', 'ESTU_COD_DEPTO_PRESENTACION', 'INST_COD_INSTITUCION']

# %%
# Seleccionar para explicar sólo el dataset de los estudiantes de Popayán
ordinal_features = ['ESTU_VALORMATRICULAUNIVERSIDAD' , 'ESTU_HORASSEMANATRABAJA' , 'FAMI_ESTRATOVIVIENDA',
                   'FAMI_EDUCACIONPADRE' , 'FAMI_EDUCACIONMADRE']
dataset_popayan = pd.read_excel(r'..\data\Datos_Popayan.xlsx')
for i in ordinal_features:
    aux = codificador_ordinales[codificador_ordinales['COLUMNA'] == i]
    dataset_popayan[i + '_ENCODED'] = dataset_popayan[i].map(dict(aux[['VALOR_ACTUAL' , 'VALOR_CODIFICADO']].values))
# Actualizar las variables ordinales
ordinal_features = [i for i in dataset_popayan.columns.tolist() if '_ENCODED' in i]
# Aplicar el Ordinal Encoder
aux_categorical = pd.DataFrame(cat_encoder.transform(dataset_popayan[categorical_yes_encoding]) , columns = categorical_yes_encoding)
# Concatenar la información
data_3 = pd.concat([aux_categorical.reset_index(drop = True),
                    dataset_popayan[ordinal_features].reset_index(drop = True),
                    dataset_popayan[categorical_no_encoding].reset_index(drop = True),
                    dataset_popayan[target].reset_index(drop = True)] , axis = 1)
# Definir los tipos de datos para las variables
for i in data_3.columns.tolist():
    if i in numeric_features or i in target:
        data_3[i] = data_3[i].fillna(-1).astype(float)
    if i in ordinal_features or i in categorical_features:
        data_3[i] = data_3[i].fillna(-1).astype(int)

X_popayan = data_3.drop(columns = target)
        
# Transformar los datos con el pipeline       
X_transformed = mejor_modelo[:-1].transform(X_popayan)

# Obtener la explicación de SHAP
explainer = shap.KernelExplainer(mejor_modelo.named_steps['catboostregressor'].predict, X_transformed)

# Calcular los valores SHAP para la instancia seleccionada
fila = 200
shap_values = explainer(X_transformed[fila : fila + 1, :])

# Colocar los labels originales
explicacion = shap.Explanation(shap_values.values, 
                  shap_values.base_values, 
                  data = X_transformed, 
                  feature_names = selected_features)

# Crear el waterfall plot
shap.plots.waterfall(explicacion[0])
# Out:
# Using 405 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# Importancia generalizada de variables
X_popayan = data_3.drop(columns = target)
        
# Transformar los datos con el pipeline       
X_transformed = mejor_modelo[:-1].transform(X_popayan)

# Obtener la explicación de SHAP
explainer = shap.KernelExplainer(mejor_modelo.named_steps['catboostregressor'].predict, shap.sample(X_transformed , 50))

# Calcular los valores SHAP para la instancia seleccionada
shap_values = explainer(X_transformed)

# Colocar los labels originales
explicacion = shap.Explanation(shap_values.values, 
                  shap_values.base_values, 
                  data = X_transformed, 
                  feature_names = selected_features)
shap.plots.bar(explicacion)
# Out:
#   0%|          | 0/405 [00:00<?, ?it/s]

# %%
# Exportar los valores shap
with open(r'..\models\shap_values.pkl', 'wb') as f:
    pickle.dump({'shap_values': shap_values.values, 'base_values': shap_values.base_values}, f)

# %%
# Ejemplo de cómo cargarlos y volverlos a usar
with open(r'..\models\shap_values.pkl', 'rb') as f:
    data = pickle.load(f)
    loaded_shap_values = data['shap_values']
    loaded_base_values = data['base_values']

# Crear un SHAP value object usando los valores cargados
shap_values_object = shap.Explanation(loaded_shap_values,
                                      base_values=loaded_base_values,
                                      feature_names = selected_features,
                                     data = X_transformed)

# Realizar un waterfall plot para una instancia específica
shap.waterfall_plot(shap_values_object[10])
shap.plots.bar(shap_values_object)
